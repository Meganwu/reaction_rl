# %% [markdown]
# # Single atom training
# This notebook goes through the workflow of setting the hyperparameters, collecting atom manipulation data, and training the deep reinforcement learning agent.

# %% [markdown]
# ### Importing modules

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
from collections import deque, namedtuple
from matplotlib import pyplot as plt, patches
import torch
from REACTRL import RealExpEnv, Episode_Memory, Createc_Controller, sac_agent, ReplayMemory, HerReplayMemory, image_process
from REACTRL import plot_graph, show_reset, show_done, show_step
matplotlib.rcParams['image.cmap'] = 'gray'
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
from matplotlib import pyplot as plt, patches
# Out:
# cpu

# %% [markdown]
# ### Setting the anchor image
# This cell retrieves the current STM scan image and use it as the template for positioning the anchor in STM images

# %%
createc_controller = Createc_Controller(None, None, None, None)
img_forward = np.array(createc_controller.stm.scandata(1,4))
#TODO
#Set the pixel of the top-left corner, widht, and height of the anchor
#If the anchor is not used, just set w and h to a small number like below
top_left, w, h = (0,0), 3, 3
#template = img_forward[top_left[1]:top_left[1]+h, top_left[0]:top_left[0]+w]
#plt.imshow(template)

template = img_forward[top_left[1]:top_left[1]+h, top_left[0]:top_left[0]+w]
plt.imshow(template)
# Out:
# succeed to connect

# %% [markdown]
# ### Set the parameters and create a RealExpEnv object

# %%
#TODO
step_nm = 0.4 #Set the radius of the manipulation start position relative the the atom start position
goal_nm  = 2 #Set the radius of the manipulation end position relative the the atom start position
max_mvolt = 15 #Set the maximum bias voltage in mV 
max_pcurrent_to_mvolt_ratio = 6E3 #Set the maximum conductance in pA/mV
max_len = 5 #Set maximum episode length
template_max_y = 3 #Set the maximum or minimum row number to search for anchor
#Set the path to load CNN weight for the atom movement classifier
CNN_weight_path = 'C:/LocalUserData/User-data/phys-asp-lab/nian_auto_spm/reaction_rl/training_data_and_model_parameters/model parameters/_atom_move_detector_conv_2460.pth'
current_jump  = 4 #Set the current jump gradient/ std(current) threshold required to take STM scan

#Set STM scan parameters
pixel = 128
im_size_nm = 5 #Image size in nm 
scan_mV = 1000 #bias voltage
x_nm, y_nm = createc_controller.get_offset_nm()
offset_nm = np.array([x_nm, y_nm]) #Set offset to current offset value

#Set manipulation parameters to pull atoms from image edge to center
pull_back_mV = 5 #bias in mV
pull_back_pA = 60000 #current in pA

#Set manipulation limit [left, right, up, down] in nm
manip_limit_nm = np.array([x_nm - 0.5*im_size_nm+0.25, x_nm + 0.5*im_size_nm-0.25, y_nm+0.25, y_nm+im_size_nm-0.25])

env = RealExpEnv(step_nm, max_mvolt, max_pcurrent_to_mvolt_ratio, goal_nm, 
                 template, current_jump, im_size_nm, offset_nm, manip_limit_nm, pixel, 
                 template_max_y, scan_mV, max_len, 
                 CNN_weight_path, 
                 bottom=False, random_scan_rate = 0.8, pull_back_mV = pull_back_mV,
                 pull_back_pA = pull_back_pA)
# Out:
# succeed to connect
# Load cnn weight

# %% [markdown]
# # Bug test  image size when operating tip_form function, the image size changes

# %%
# initial scan_image

result=env.createc_controller.scan_image()
# Out:
# The scan will take 127.1 seconds
# offset_test0000 [-0. -0.]
# offset_test1111 [-0. -0.]
# offset_test2222 [-0. -0.]

# %%
plt.figure(figsize=(4,4))
plt.subplot(1,2,1)
plt.imshow(result[0])
plt.subplot(1,2,2)
plt.imshow(result[1])

# %% [markdown]
# # Basic parameters

# %%
basic_params=['Delta X[Dac]', 'Delta Y[Dac]', 'Num.X', 'Num.Y', 'Delay X+', 'Delay X-', 'Delay Y', 'DX/DDeltaX','GainX','GainY','GainZ', 'Rotation', 'BiasVolt.[mV]', 'GainPre 10^', 'ScanChannels', 'PlanDx', 'PlanDy', 'OffsetX', 'OffsetY', 'ZPiezoconst', 'XPiezoconst', 'YPiezoconst', 'RepeatRotinc', 'RptBVoltinc', 'Repeatinterval', 'Repeatcounter', 'RepeatXoffset', 'RepeatYoffset', 'Scantype', 'ScanXMode', 'Scancoarse', 'CHMode', 'Channels', 'Preamptype', 'VFBMode', 'RotCMode', 'ScanYMode', 'ScanYDirec']
for i in basic_params:
    print(env.createc_controller.stm.getparam(i))
print(env.createc_controller.stm.getparam('Length x[A]'))
print(env.createc_controller.stm.getparam('Length y[A]'))
print(env.createc_controller.im_size_nm)
print(env.createc_controller.stm.getparam("GainX"))
print(env.createc_controller.stm.getparam("GainY"))
print(env.createc_controller.stm.getparam("GainZ"))

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,4,1)
plt.imshow(result[0])
plt.subplot(1,4,2)
plt.imshow(result[1])

# %% [markdown]
# # parameters change after tip_form

# %%
# env.createc_controller.ramp_bias_mV(-1.2)
env.createc_controller.tip_form(2, 104, 40)

# %%
env.createc_controller.set_Z_approach(10)        
env.createc_controller.stm.btn_tipform(200, 10)

# %%
print(env.createc_controller.stm.getparam('Length x[A]'))
print(env.createc_controller.stm.getparam('Length y[A]'))
print(env.createc_controller.im_size_nm)
print(env.createc_controller.stm.getparam("GainX"))
print(env.createc_controller.stm.getparam("GainY"))
print(env.createc_controller.stm.getparam("GainZ"))
# Out:
# 149.9557
# 149.9557
# 15
# 10
# 10
# 10

# %%
env.createc_controller.pixel
# Out:
# 128

# %%
env.createc_controller.offset_nm=np.array([110,  50])

# %%
results=env.createc_controller.scan_image()   # problem: long scanning time, even never terminate
# Out:
# The scan will take 127.8 seconds
# offset_test0000 [110  50]
# offset_test1111 [110  50]
# offset_test2222 [110  50]

# %%
results[]

# %% [markdown]
# # change parameters

# %%
env.createc_controller.stm.setparam('GainX',10)
GainX = float(env.createc_controller.stm.getparam("GainX"))
env.createc_controller.stm.setparam('GainY',10)
GainY = float(env.createc_controller.stm.getparam("GainY"))
env.createc_controller.stm.setparam('GainZ',3)
GainZ = float(env.createc_controller.stm.getparam("GainZ"))
env.createc_controller.im_size_nm=5
# env.createc_controller.stm.setparam('Delta X [Dac]',59)
env.createc_controller.get_Delta_X(5)
# Out:
# 59

# %%
env.createc_controller.scan_image() # problem: long scanning time, even never terminate, although change the paramters as this way
# Out:
# The scan will take 12.5 seconds
# offset_test0000 [-50.84006882  86.99994049]
# offset_test1111 [-50.84006882  86.99994049]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25232\2440502613.py in <module>
# ----> 1 env.createc_controller.scan_image() # problem: long scanning time, even never terminate, although change the paramters as this way
#
# ~\github\reaction_rl\REACTRL\env_modules\createc_control.py in scan_image(self, DIR_NAME, BASE_NAME, counter, save, speed)
#     114         time.sleep(scan_time -2)
#     115         while True:
# --> 116             time.sleep(2)
#     117             scanstatus = self.stm.scanstatus
#     118             if scanstatus!=2:
#
# KeyboardInterrupt:

# %% [markdown]
# #  check what happens

# %%
env.createc_controller.stm.scanstart()
env.createc_controller.stm.scanstatus  # always keep the scanstatus as 2 i.e. running state
# Out:
# 2

# %%
env.createc_controller.stm.scanstart() #Starts a new STM scan. Similar to pressing the button Scanstart
print('aaaa')
while True:

    scanstatus = env.createc_controller.stm.scanstatus
    print('bbb')
    if scanstatus!=2:
        break

# %% [markdown]
# # Test spiral trajectory

# %%
env.computeLocationIDs()
points=env.computeLocationIDs()
all_x=np.array([i[0] for i in points])
all_y=np.array([i[1] for i in points])
ref_x=1
ref_y=5
cellsize=10
for point in range(len(points)):
    i=points[point][0]
    j=points[point][1]
    plt.scatter(ref_x+i*cellsize,ref_y+j*cellsize)
    plt.gca().add_patch(patches.Rectangle((ref_x+i*cellsize-5,  ref_y+j*cellsize), 10, 10, fill=True, edgecolor='grey', lw=2))
    
    
plt.plot(ref_x+all_x*cellsize,ref_y+all_y*cellsize)

# %%
env.tip_form_modify(6, 10, 100, 10)

# %%
plt.imshow(results[0], extent=[-5, 5, -5, 5])

# %%
plt.imshow(result[0], extent=[new_x_a-5, new_x_a+5, new_y_a-5, new_y_a+5])

# %%
new_x_a=50
new_y_a=50
radius=35
check_similarity=[]
check_similarity.append([new_x_a, new_y_a])
upper_limit_move=400

found=False
epoch=0

# plt.figure(figsize=(16,160))
# plt.subplot(40,4,1)
# plt.imshow(results[0])




while not found:
    plt.text(new_x_a, new_y_a+5, epoch)
#     env.switch_approach_area()
#     env.ForbiddenArea(forbiden_radius=radius)
#     plt.gca().add_patch(patches.Circle((new_x_a, new_y_a), radius, fill=False))
    new_x_a, new_y_a=env.GetNextGoodClosest(new_x_a, new_y_a, initial_x=50, initial_y=50, forbiden_radius=radius, upper_limit_move=upper_limit_move,approach_limit=[-130, 230, -130, 230],check_similarity=check_similarity) 
#     plt.subplot(40,4,epoch+1)
    if epoch+1==6:
        env.createc_controller.im_size_nm=env.createc_controller.im_size_nm*2
        env.createc_controller.offset_nm=np.array([new_x_a, new_x_a])
        result=env.createc_controller.scan_image()
        plt.imshow(result[0], extent=[new_x_a-10*2, new_x_a+10*2, new_y_a-10*2, new_y_a+10*2])
        env.createc_controller.im_size_nm=env.createc_controller.im_size_nm/2
    else:
        env.createc_controller.offset_nm=np.array([new_x_a, new_x_a])
        result=env.createc_controller.scan_image()
        plt.imshow(result[0], extent=[new_x_a-10, new_x_a+10, new_y_a-10, new_y_a+10])
        
#     plt.imshow(result[0], extent=[new_x_a-10, new_x_a+10, new_y_a-10, new_y_a+10])
    
    print(new_x_a, new_y_a, radius)
    
    if  new_x_a==None:
        
        new_x_a, new_y_a=check_similarity[-1][0], check_similarity[-1][1]
        plt.gca().add_patch(patches.Circle((new_x_a, new_y_a), radius, fill=False, color='yellow'))
        radius=radius*2
        env.max_radius=300
        upper_limit_move=upper_limit_move+20000
#         plt.gca().add_patch(patches.Circle((new_x_a, new_y_a), radius, fill=False, color='yellow'))    
    else:
        radius=35
        env.max_radius=150
        upper_limit_move=400
#         plt.gca().add_patch(patches.Circle((new_x_a, new_y_a), radius, fill=False))
    
    if radius>1000:
        break
        
    check_similarity.append([new_x_a, new_y_a])
        
#     plt.gca().add_patch(patches.Circle((new_x_a, new_y_a), radius, fill=False))
    if new_y_a<-59:
        found=True
    epoch=epoch+1
        
plt.plot([i[0] for i in check_similarity], [i[1] for i in check_similarity])
plt.xlim(-100, 190)
plt.ylim(-100, 190)
plt.savefig('path2.png')
# Out:
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 0 4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [20 20]
# offset_test1111 [20 20]
# offset_test2222 [20 20]
# 20 30 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 0 4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [50 50]
# offset_test1111 [50 50]
# offset_test2222 [50 50]
# 50 10 35
# starting new approach area...
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [80 80]
# offset_test1111 [80 80]
# offset_test2222 [80 80]
# 80 30 35
# starting new approach area...
# 0 -4 80.0 40 40.0 80.0
# 0 4 80.0 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [100 100]
# offset_test1111 [100 100]
# offset_test2222 [100 100]
# 100 60 35
# starting new approach area...
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [70 70]
# offset_test1111 [70 70]
# offset_test2222 [70 70]
# 70 80 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [40 40]
# offset_test1111 [40 40]
# offset_test2222 [40 40]
# 40 100 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [20 20]
# offset_test1111 [20 20]
# offset_test2222 [20 20]
# 20 70 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [-10 -10]
# offset_test1111 [-10 -10]
# offset_test2222 [-10 -10]
# -10 50 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 0 4 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [-30 -30]
# offset_test1111 [-30 -30]
# offset_test2222 [-30 -30]
# -30 20 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [0 0]
# offset_test1111 [0 0]
# offset_test2222 [0 0]
# 0 0 35
# starting new approach area...
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [30 30]
# offset_test1111 [30 30]
# offset_test2222 [30 30]
# 30 -20 35
# starting new approach area...
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [60 60]
# offset_test1111 [60 60]
# offset_test2222 [60 60]
# 60 -40 35
# starting new approach area...
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [80 80]
# offset_test1111 [80 80]
# offset_test2222 [80 80]
# 80 -10 35
# starting new approach area...
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [110 110]
# offset_test1111 [110 110]
# offset_test2222 [110 110]
# 110 10 35
# starting new approach area...
# 0 -4 80.0 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [130 130]
# offset_test1111 [130 130]
# offset_test2222 [130 130]
# 130 40 35
# starting new approach area...
# 0 4 80.0 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [150 150]
# offset_test1111 [150 150]
# offset_test2222 [150 150]
# 150 70 35
# starting new approach area...
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [120 120]
# offset_test1111 [120 120]
# offset_test2222 [120 120]
# 120 90 35
# starting new approach area...
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [90 90]
# offset_test1111 [90 90]
# offset_test2222 [90 90]
# 90 110 35
# starting new approach area...
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [60 60]
# offset_test1111 [60 60]
# offset_test2222 [60 60]
# 60 130 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [30 30]
# offset_test1111 [30 30]
# offset_test2222 [30 30]
# 30 150 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [10 10]
# offset_test1111 [10 10]
# offset_test2222 [10 10]
# 10 120 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [-10 -10]
# offset_test1111 [-10 -10]
# offset_test2222 [-10 -10]
# -10 90 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [-40 -40]
# offset_test1111 [-40 -40]
# offset_test2222 [-40 -40]
# -40 70 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [-60 -60]
# offset_test1111 [-60 -60]
# offset_test2222 [-60 -60]
# -60 40 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [-80 -80]
# offset_test1111 [-80 -80]
# offset_test2222 [-80 -80]
# -80 70 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [-60 -60]
# offset_test1111 [-60 -60]
# offset_test2222 [-60 -60]
# -60 100 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [-30 -30]
# offset_test1111 [-30 -30]
# offset_test2222 [-30 -30]
# -30 120 35
# starting new approach area...
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [-10 -10]
# offset_test1111 [-10 -10]
# offset_test2222 [-10 -10]
# -10 150 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [10 10]
# offset_test1111 [10 10]
# offset_test2222 [10 10]
# 10 180 35
# starting new approach area...
# -4 0 80.0 40 40.0 80.0
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 4 66.05551275463989 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [40 40]
# offset_test1111 [40 40]
# offset_test2222 [40 40]
# 40 200 35
# starting new approach area...
# -3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [60 60]
# offset_test1111 [60 60]
# offset_test2222 [60 60]
# 60 170 35
# starting new approach area...
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [90 90]
# offset_test1111 [90 90]
# offset_test2222 [90 90]
# 90 150 35
# starting new approach area...
# 0 4 80.0 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [120 120]
# offset_test1111 [120 120]
# offset_test2222 [120 120]
# 120 130 35
# starting new approach area...
# 0 4 80.0 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [150 150]
# offset_test1111 [150 150]
# offset_test2222 [150 150]
# 150 110 35
# starting new approach area...
# 0 4 80.0 40 40.0 80.0
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [180 180]
# offset_test1111 [180 180]
# offset_test2222 [180 180]
# 180 90 35
# starting new approach area...
# 0 -4 80.0 40 40.0 80.0
# 0 4 80.0 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [200 200]
# offset_test1111 [200 200]
# offset_test2222 [200 200]
# 200 60 35
# starting new approach area...
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 2 3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [170 170]
# offset_test1111 [170 170]
# offset_test2222 [170 170]
# 170 40 35
# starting new approach area...
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [150 150]
# offset_test1111 [150 150]
# offset_test2222 [150 150]
# 150 10 35
# starting new approach area...
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [130 130]
# offset_test1111 [130 130]
# offset_test2222 [130 130]
# 130 -20 35
# starting new approach area...
# -3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# 4 0 66.05551275463989 40 40.0 80.0
# The scan will take 127.1 seconds
# offset_test0000 [100 100]
# offset_test1111 [100 100]
# offset_test2222 [100 100]
# 100 -40 35
# starting new approach area...
# -2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 0 -4 66.05551275463989 40 40.0 80.0
# 2 -3 66.05551275463989 30 36.05551275463989 66.05551275463989
# 3 -2 66.05551275463989 30 36.05551275463989 66.05551275463989
# The scan will take 127.1 seconds
# offset_test0000 [80 80]
# offset_test1111 [80 80]
# offset_test2222 [80 80]
# 80 -70 35

# %%
plt.plot([i[0] for i in check_similarity], [i[1] for i in check_similarity])

# %%
new_x_a=0
new_y_a=0
radius=1
euclid_limit=12
leg=0
check_similarity=[]
for epoch in range(20):
    check_similarity.append([new_x_a, new_y_a])
    new_x_a, new_y_a=select_point(ref_x=new_x_a, ref_y=new_y_a, epoch=epoch, check_similarity=check_similarity, leg=leg, radius=radius, euclid_limit=euclid_limit, approach_limit=[-50, 50, -50, 50])
    if [new_x_a, new_y_a]==check_similarity[-1]:
        radius=radius*2
        euclid_limit=euclid_limit+8
    else:
        radius=2
        euclid_limit=8

    if radius>24:
        break
# Out:
# C:\Users\wun2\AppData\Local\Temp\ipykernel_1868\446068200.py:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros((2*num_points+1,2*num_points+1), dtype=np.bool)
# The scan will take 12.5 seconds
# offset_test0000 [2 0]
# offset_test1111 [2 0]
# offset_test2222 [2 0]
# The scan will take 12.5 seconds
# offset_test0000 [2 2]
# offset_test1111 [2 2]
# offset_test2222 [2 2]
# The scan will take 12.5 seconds
# offset_test0000 [0 2]
# offset_test1111 [0 2]
# offset_test2222 [0 2]
# The scan will take 12.5 seconds
# offset_test0000 [-2  2]
# offset_test1111 [-2  2]
# offset_test2222 [-2  2]
# The scan will take 12.5 seconds
# offset_test0000 [-2  0]
# offset_test1111 [-2  0]
# offset_test2222 [-2  0]
# The scan will take 12.5 seconds
# offset_test0000 [-2 -2]
# offset_test1111 [-2 -2]
# offset_test2222 [-2 -2]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 -2]
# offset_test1111 [ 0 -2]
# offset_test2222 [ 0 -2]
# The scan will take 12.5 seconds
# offset_test0000 [ 2 -2]
# offset_test1111 [ 2 -2]
# offset_test2222 [ 2 -2]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 -2]
# offset_test1111 [ 4 -2]
# offset_test2222 [ 4 -2]
# The scan will take 12.5 seconds
# offset_test0000 [4 0]
# offset_test1111 [4 0]
# offset_test2222 [4 0]
# The scan will take 12.5 seconds
# offset_test0000 [4 2]
# offset_test1111 [4 2]
# offset_test2222 [4 2]
# The scan will take 12.5 seconds
# offset_test0000 [4 4]
# offset_test1111 [4 4]
# offset_test2222 [4 4]
# The scan will take 12.5 seconds
# offset_test0000 [2 4]
# offset_test1111 [2 4]
# offset_test2222 [2 4]
# The scan will take 12.5 seconds
# offset_test0000 [0 4]
# offset_test1111 [0 4]
# offset_test2222 [0 4]
# The scan will take 12.5 seconds
# offset_test0000 [-2  4]
# offset_test1111 [-2  4]
# offset_test2222 [-2  4]
# The scan will take 12.5 seconds
# offset_test0000 [-4  4]
# offset_test1111 [-4  4]
# offset_test2222 [-4  4]
# The scan will take 12.5 seconds
# offset_test0000 [-4  2]
# offset_test1111 [-4  2]
# offset_test2222 [-4  2]
# The scan will take 12.5 seconds
# offset_test0000 [-4  0]
# offset_test1111 [-4  0]
# offset_test2222 [-4  0]
# The scan will take 12.5 seconds
# offset_test0000 [-4 -2]
# offset_test1111 [-4 -2]
# offset_test2222 [-4 -2]
# The scan will take 12.5 seconds
# offset_test0000 [-4 -4]
# offset_test1111 [-4 -4]
# offset_test2222 [-4 -4]
# The scan will take 12.5 seconds
# offset_test0000 [-2 -4]
# offset_test1111 [-2 -4]
# offset_test2222 [-2 -4]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 -4]
# offset_test1111 [ 0 -4]
# offset_test2222 [ 0 -4]
# The scan will take 12.5 seconds
# offset_test0000 [ 2 -4]
# offset_test1111 [ 2 -4]
# offset_test2222 [ 2 -4]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 -4]
# offset_test1111 [ 4 -4]
# offset_test2222 [ 4 -4]
# The scan will take 12.5 seconds
# offset_test0000 [ 6 -4]
# offset_test1111 [ 6 -4]
# offset_test2222 [ 6 -4]
# The scan will take 12.5 seconds
# offset_test0000 [ 6 -2]
# offset_test1111 [ 6 -2]
# offset_test2222 [ 6 -2]
# The scan will take 12.5 seconds
# offset_test0000 [6 0]
# offset_test1111 [6 0]
# offset_test2222 [6 0]
# The scan will take 12.5 seconds
# offset_test0000 [6 2]
# offset_test1111 [6 2]
# offset_test2222 [6 2]
# The scan will take 12.5 seconds
# offset_test0000 [6 4]
# offset_test1111 [6 4]
# offset_test2222 [6 4]
# The scan will take 12.5 seconds
# offset_test0000 [6 6]
# offset_test1111 [6 6]
# offset_test2222 [6 6]
# The scan will take 12.5 seconds
# offset_test0000 [4 6]
# offset_test1111 [4 6]
# offset_test2222 [4 6]
# The scan will take 12.5 seconds
# offset_test0000 [2 6]
# offset_test1111 [2 6]
# offset_test2222 [2 6]
# The scan will take 12.5 seconds
# offset_test0000 [0 6]
# offset_test1111 [0 6]
# offset_test2222 [0 6]
# The scan will take 12.5 seconds
# offset_test0000 [-2  6]
# offset_test1111 [-2  6]
# offset_test2222 [-2  6]
# The scan will take 12.5 seconds
# offset_test0000 [-4  6]
# offset_test1111 [-4  6]
# offset_test2222 [-4  6]
# The scan will take 12.5 seconds
# offset_test0000 [-6  6]
# offset_test1111 [-6  6]
# offset_test2222 [-6  6]
# The scan will take 12.5 seconds
# offset_test0000 [-6  4]
# offset_test1111 [-6  4]
# offset_test2222 [-6  4]
# The scan will take 12.5 seconds
# offset_test0000 [-6  2]
# offset_test1111 [-6  2]
# offset_test2222 [-6  2]
# The scan will take 12.5 seconds
# offset_test0000 [-6  0]
# offset_test1111 [-6  0]
# offset_test2222 [-6  0]
# The scan will take 12.5 seconds
# offset_test0000 [-6 -2]
# offset_test1111 [-6 -2]
# offset_test2222 [-6 -2]
# The scan will take 12.5 seconds
# offset_test0000 [-6 -4]
# offset_test1111 [-6 -4]
# offset_test2222 [-6 -4]
# The scan will take 12.5 seconds
# offset_test0000 [-6 -6]
# offset_test1111 [-6 -6]
# offset_test2222 [-6 -6]
# The scan will take 12.5 seconds
# offset_test0000 [-4 -6]
# offset_test1111 [-4 -6]
# offset_test2222 [-4 -6]
# The scan will take 12.5 seconds
# offset_test0000 [-2 -6]
# offset_test1111 [-2 -6]
# offset_test2222 [-2 -6]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 -6]
# offset_test1111 [ 0 -6]
# offset_test2222 [ 0 -6]
# The scan will take 12.5 seconds
# offset_test0000 [ 2 -6]
# offset_test1111 [ 2 -6]
# offset_test2222 [ 2 -6]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 -6]
# offset_test1111 [ 4 -6]
# offset_test2222 [ 4 -6]
# The scan will take 12.5 seconds
# offset_test0000 [ 6 -6]
# offset_test1111 [ 6 -6]
# offset_test2222 [ 6 -6]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 -6]
# offset_test1111 [ 8 -6]
# offset_test2222 [ 8 -6]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 -4]
# offset_test1111 [ 8 -4]
# offset_test2222 [ 8 -4]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 -2]
# offset_test1111 [ 8 -2]
# offset_test2222 [ 8 -2]
# The scan will take 12.5 seconds
# offset_test0000 [8 0]
# offset_test1111 [8 0]
# offset_test2222 [8 0]
# The scan will take 12.5 seconds
# offset_test0000 [8 2]
# offset_test1111 [8 2]
# offset_test2222 [8 2]
# The scan will take 12.5 seconds
# offset_test0000 [8 4]
# offset_test1111 [8 4]
# offset_test2222 [8 4]
# The scan will take 12.5 seconds
# offset_test0000 [8 6]
# offset_test1111 [8 6]
# offset_test2222 [8 6]
# The scan will take 12.5 seconds
# offset_test0000 [8 8]
# offset_test1111 [8 8]
# offset_test2222 [8 8]
# The scan will take 12.5 seconds
# offset_test0000 [6 8]
# offset_test1111 [6 8]
# offset_test2222 [6 8]
# The scan will take 12.5 seconds
# offset_test0000 [4 8]
# offset_test1111 [4 8]
# offset_test2222 [4 8]
# The scan will take 12.5 seconds
# offset_test0000 [2 8]
# offset_test1111 [2 8]
# offset_test2222 [2 8]
# The scan will take 12.5 seconds
# offset_test0000 [0 8]
# offset_test1111 [0 8]
# offset_test2222 [0 8]
# The scan will take 12.5 seconds
# offset_test0000 [-2  8]
# offset_test1111 [-2  8]
# offset_test2222 [-2  8]
# The scan will take 12.5 seconds
# offset_test0000 [-4  8]
# offset_test1111 [-4  8]
# offset_test2222 [-4  8]
# The scan will take 12.5 seconds
# offset_test0000 [-6  8]
# offset_test1111 [-6  8]
# offset_test2222 [-6  8]
# The scan will take 12.5 seconds
# offset_test0000 [-8  8]
# offset_test1111 [-8  8]
# offset_test2222 [-8  8]
# The scan will take 12.5 seconds
# offset_test0000 [-8  6]
# offset_test1111 [-8  6]
# offset_test2222 [-8  6]
# The scan will take 12.5 seconds
# offset_test0000 [-8  4]
# offset_test1111 [-8  4]
# offset_test2222 [-8  4]
# The scan will take 12.5 seconds
# offset_test0000 [-8  2]
# offset_test1111 [-8  2]
# offset_test2222 [-8  2]
# The scan will take 12.5 seconds
# offset_test0000 [-8  0]
# offset_test1111 [-8  0]
# offset_test2222 [-8  0]
# The scan will take 12.5 seconds
# offset_test0000 [-8 -2]
# offset_test1111 [-8 -2]
# offset_test2222 [-8 -2]
# The scan will take 12.5 seconds
# offset_test0000 [-8 -4]
# offset_test1111 [-8 -4]
# offset_test2222 [-8 -4]
# The scan will take 12.5 seconds
# offset_test0000 [-8 -6]
# offset_test1111 [-8 -6]
# offset_test2222 [-8 -6]
# The scan will take 12.5 seconds
# offset_test0000 [-8 -8]
# offset_test1111 [-8 -8]
# offset_test2222 [-8 -8]
# The scan will take 12.5 seconds
# offset_test0000 [-6 -8]
# offset_test1111 [-6 -8]
# offset_test2222 [-6 -8]
# The scan will take 12.5 seconds
# offset_test0000 [-4 -8]
# offset_test1111 [-4 -8]
# offset_test2222 [-4 -8]
# The scan will take 12.5 seconds
# offset_test0000 [-2 -8]
# offset_test1111 [-2 -8]
# offset_test2222 [-2 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 -8]
# offset_test1111 [ 0 -8]
# offset_test2222 [ 0 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 2 -8]
# offset_test1111 [ 2 -8]
# offset_test2222 [ 2 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 -8]
# offset_test1111 [ 4 -8]
# offset_test2222 [ 4 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 6 -8]
# offset_test1111 [ 6 -8]
# offset_test2222 [ 6 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 -8]
# offset_test1111 [ 8 -8]
# offset_test2222 [ 8 -8]
# The scan will take 12.5 seconds
# offset_test0000 [4 0]
# offset_test1111 [4 0]
# offset_test2222 [4 0]
# The scan will take 12.5 seconds
# offset_test0000 [4 4]
# offset_test1111 [4 4]
# offset_test2222 [4 4]
# The scan will take 12.5 seconds
# offset_test0000 [0 4]
# offset_test1111 [0 4]
# offset_test2222 [0 4]
# The scan will take 12.5 seconds
# offset_test0000 [-4  4]
# offset_test1111 [-4  4]
# offset_test2222 [-4  4]
# The scan will take 12.5 seconds
# offset_test0000 [-4  0]
# offset_test1111 [-4  0]
# offset_test2222 [-4  0]
# The scan will take 12.5 seconds
# offset_test0000 [-4 -4]
# offset_test1111 [-4 -4]
# offset_test2222 [-4 -4]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 -4]
# offset_test1111 [ 0 -4]
# offset_test2222 [ 0 -4]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 -4]
# offset_test1111 [ 4 -4]
# offset_test2222 [ 4 -4]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 -4]
# offset_test1111 [ 8 -4]
# offset_test2222 [ 8 -4]
# The scan will take 12.5 seconds
# offset_test0000 [8 0]
# offset_test1111 [8 0]
# offset_test2222 [8 0]
# The scan will take 12.5 seconds
# offset_test0000 [8 4]
# offset_test1111 [8 4]
# offset_test2222 [8 4]
# The scan will take 12.5 seconds
# offset_test0000 [8 8]
# offset_test1111 [8 8]
# offset_test2222 [8 8]
# The scan will take 12.5 seconds
# offset_test0000 [4 8]
# offset_test1111 [4 8]
# offset_test2222 [4 8]
# The scan will take 12.5 seconds
# offset_test0000 [0 8]
# offset_test1111 [0 8]
# offset_test2222 [0 8]
# The scan will take 12.5 seconds
# offset_test0000 [-4  8]
# offset_test1111 [-4  8]
# offset_test2222 [-4  8]
# The scan will take 12.5 seconds
# offset_test0000 [-8  8]
# offset_test1111 [-8  8]
# offset_test2222 [-8  8]
# The scan will take 12.5 seconds
# offset_test0000 [-8  4]
# offset_test1111 [-8  4]
# offset_test2222 [-8  4]
# The scan will take 12.5 seconds
# offset_test0000 [-8  0]
# offset_test1111 [-8  0]
# offset_test2222 [-8  0]
# The scan will take 12.5 seconds
# offset_test0000 [-8 -4]
# offset_test1111 [-8 -4]
# offset_test2222 [-8 -4]
# The scan will take 12.5 seconds
# offset_test0000 [-8 -8]
# offset_test1111 [-8 -8]
# offset_test2222 [-8 -8]
# The scan will take 12.5 seconds
# offset_test0000 [-4 -8]
# offset_test1111 [-4 -8]
# offset_test2222 [-4 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 -8]
# offset_test1111 [ 0 -8]
# offset_test2222 [ 0 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 -8]
# offset_test1111 [ 4 -8]
# offset_test2222 [ 4 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 -8]
# offset_test1111 [ 8 -8]
# offset_test2222 [ 8 -8]
# The scan will take 12.5 seconds
# offset_test0000 [12 -8]
# offset_test1111 [12 -8]
# offset_test2222 [12 -8]
# The scan will take 12.5 seconds
# offset_test0000 [12 -4]
# offset_test1111 [12 -4]
# offset_test2222 [12 -4]
# The scan will take 12.5 seconds
# offset_test0000 [12  0]
# offset_test1111 [12  0]
# offset_test2222 [12  0]
# The scan will take 12.5 seconds
# offset_test0000 [12  4]
# offset_test1111 [12  4]
# offset_test2222 [12  4]
# The scan will take 12.5 seconds
# offset_test0000 [12  8]
# offset_test1111 [12  8]
# offset_test2222 [12  8]
# The scan will take 12.5 seconds
# offset_test0000 [12 12]
# offset_test1111 [12 12]
# offset_test2222 [12 12]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 12]
# offset_test1111 [ 8 12]
# offset_test2222 [ 8 12]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 12]
# offset_test1111 [ 4 12]
# offset_test2222 [ 4 12]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 12]
# offset_test1111 [ 0 12]
# offset_test2222 [ 0 12]
# The scan will take 12.5 seconds
# offset_test0000 [-4 12]
# offset_test1111 [-4 12]
# offset_test2222 [-4 12]
# The scan will take 12.5 seconds
# offset_test0000 [-8 12]
# offset_test1111 [-8 12]
# offset_test2222 [-8 12]
# The scan will take 12.5 seconds
# offset_test0000 [-12  12]
# offset_test1111 [-12  12]
# offset_test2222 [-12  12]
# The scan will take 12.5 seconds
# offset_test0000 [-12   8]
# offset_test1111 [-12   8]
# offset_test2222 [-12   8]
# The scan will take 12.5 seconds
# offset_test0000 [-12   4]
# offset_test1111 [-12   4]
# offset_test2222 [-12   4]
# The scan will take 12.5 seconds
# offset_test0000 [-12   0]
# offset_test1111 [-12   0]
# offset_test2222 [-12   0]
# The scan will take 12.5 seconds
# offset_test0000 [-12  -4]
# offset_test1111 [-12  -4]
# offset_test2222 [-12  -4]
# The scan will take 12.5 seconds
# offset_test0000 [-12  -8]
# offset_test1111 [-12  -8]
# offset_test2222 [-12  -8]
# The scan will take 12.5 seconds
# offset_test0000 [-12 -12]
# offset_test1111 [-12 -12]
# offset_test2222 [-12 -12]
# The scan will take 12.5 seconds
# offset_test0000 [ -8 -12]
# offset_test1111 [ -8 -12]
# offset_test2222 [ -8 -12]
# The scan will take 12.5 seconds
# offset_test0000 [ -4 -12]
# offset_test1111 [ -4 -12]
# offset_test2222 [ -4 -12]
# The scan will take 12.5 seconds
# offset_test0000 [  0 -12]
# offset_test1111 [  0 -12]
# offset_test2222 [  0 -12]
# The scan will take 12.5 seconds
# offset_test0000 [  4 -12]
# offset_test1111 [  4 -12]
# offset_test2222 [  4 -12]
# The scan will take 12.5 seconds
# offset_test0000 [  8 -12]
# offset_test1111 [  8 -12]
# offset_test2222 [  8 -12]
# The scan will take 12.5 seconds
# offset_test0000 [ 12 -12]
# offset_test1111 [ 12 -12]
# offset_test2222 [ 12 -12]
# The scan will take 12.5 seconds
# offset_test0000 [16 -8]
# offset_test1111 [16 -8]
# offset_test2222 [16 -8]
# The scan will take 12.5 seconds
# offset_test0000 [16 -4]
# offset_test1111 [16 -4]
# offset_test2222 [16 -4]
# The scan will take 12.5 seconds
# offset_test0000 [16  0]
# offset_test1111 [16  0]
# offset_test2222 [16  0]
# The scan will take 12.5 seconds
# offset_test0000 [16  4]
# offset_test1111 [16  4]
# offset_test2222 [16  4]
# The scan will take 12.5 seconds
# offset_test0000 [16  8]
# offset_test1111 [16  8]
# offset_test2222 [16  8]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 16]
# offset_test1111 [ 8 16]
# offset_test2222 [ 8 16]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 16]
# offset_test1111 [ 4 16]
# offset_test2222 [ 4 16]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 16]
# offset_test1111 [ 0 16]
# offset_test2222 [ 0 16]
# The scan will take 12.5 seconds
# offset_test0000 [-4 16]
# offset_test1111 [-4 16]
# offset_test2222 [-4 16]
# The scan will take 12.5 seconds
# offset_test0000 [-8 16]
# offset_test1111 [-8 16]
# offset_test2222 [-8 16]
# The scan will take 12.5 seconds
# offset_test0000 [-16   8]
# offset_test1111 [-16   8]
# offset_test2222 [-16   8]
# The scan will take 12.5 seconds
# offset_test0000 [-16   4]
# offset_test1111 [-16   4]
# offset_test2222 [-16   4]
# The scan will take 12.5 seconds
# offset_test0000 [-16   0]
# offset_test1111 [-16   0]
# offset_test2222 [-16   0]
# The scan will take 12.5 seconds
# offset_test0000 [-16  -4]
# offset_test1111 [-16  -4]
# offset_test2222 [-16  -4]
# The scan will take 12.5 seconds
# offset_test0000 [-16  -8]
# offset_test1111 [-16  -8]
# offset_test2222 [-16  -8]
# The scan will take 12.5 seconds
# offset_test0000 [ -8 -16]
# offset_test1111 [ -8 -16]
# offset_test2222 [ -8 -16]
# The scan will take 12.5 seconds
# offset_test0000 [ -4 -16]
# offset_test1111 [ -4 -16]
# offset_test2222 [ -4 -16]
# The scan will take 12.5 seconds
# offset_test0000 [  0 -16]
# offset_test1111 [  0 -16]
# offset_test2222 [  0 -16]
# The scan will take 12.5 seconds
# offset_test0000 [  4 -16]
# offset_test1111 [  4 -16]
# offset_test2222 [  4 -16]
# The scan will take 12.5 seconds
# offset_test0000 [  8 -16]
# offset_test1111 [  8 -16]
# offset_test2222 [  8 -16]
# The scan will take 12.5 seconds
# offset_test0000 [8 0]
# offset_test1111 [8 0]
# offset_test2222 [8 0]
# The scan will take 12.5 seconds
# offset_test0000 [8 8]
# offset_test1111 [8 8]
# offset_test2222 [8 8]
# The scan will take 12.5 seconds
# offset_test0000 [0 8]
# offset_test1111 [0 8]
# offset_test2222 [0 8]
# The scan will take 12.5 seconds
# offset_test0000 [-8  8]
# offset_test1111 [-8  8]
# offset_test2222 [-8  8]
# The scan will take 12.5 seconds
# offset_test0000 [-8  0]
# offset_test1111 [-8  0]
# offset_test2222 [-8  0]
# The scan will take 12.5 seconds
# offset_test0000 [-8 -8]
# offset_test1111 [-8 -8]
# offset_test2222 [-8 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 -8]
# offset_test1111 [ 0 -8]
# offset_test2222 [ 0 -8]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 -8]
# offset_test1111 [ 8 -8]
# offset_test2222 [ 8 -8]
# The scan will take 12.5 seconds
# offset_test0000 [16 -8]
# offset_test1111 [16 -8]
# offset_test2222 [16 -8]
# The scan will take 12.5 seconds
# offset_test0000 [16  0]
# offset_test1111 [16  0]
# offset_test2222 [16  0]
# The scan will take 12.5 seconds
# offset_test0000 [16  8]
# offset_test1111 [16  8]
# offset_test2222 [16  8]
# The scan will take 12.5 seconds
# offset_test0000 [16 16]
# offset_test1111 [16 16]
# offset_test2222 [16 16]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 16]
# offset_test1111 [ 8 16]
# offset_test2222 [ 8 16]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 16]
# offset_test1111 [ 0 16]
# offset_test2222 [ 0 16]
# The scan will take 12.5 seconds
# offset_test0000 [-8 16]
# offset_test1111 [-8 16]
# offset_test2222 [-8 16]
# The scan will take 12.5 seconds
# offset_test0000 [-16  16]
# offset_test1111 [-16  16]
# offset_test2222 [-16  16]
# The scan will take 12.5 seconds
# offset_test0000 [-16   8]
# offset_test1111 [-16   8]
# offset_test2222 [-16   8]
# The scan will take 12.5 seconds
# offset_test0000 [-16   0]
# offset_test1111 [-16   0]
# offset_test2222 [-16   0]
# The scan will take 12.5 seconds
# offset_test0000 [-16  -8]
# offset_test1111 [-16  -8]
# offset_test2222 [-16  -8]
# The scan will take 12.5 seconds
# offset_test0000 [-16 -16]
# offset_test1111 [-16 -16]
# offset_test2222 [-16 -16]
# The scan will take 12.5 seconds
# offset_test0000 [ -8 -16]
# offset_test1111 [ -8 -16]
# offset_test2222 [ -8 -16]
# The scan will take 12.5 seconds
# offset_test0000 [  0 -16]
# offset_test1111 [  0 -16]
# offset_test2222 [  0 -16]
# The scan will take 12.5 seconds
# offset_test0000 [  8 -16]
# offset_test1111 [  8 -16]
# offset_test2222 [  8 -16]
# The scan will take 12.5 seconds
# offset_test0000 [ 16 -16]
# offset_test1111 [ 16 -16]
# offset_test2222 [ 16 -16]
# The scan will take 12.5 seconds
# offset_test0000 [24 -8]
# offset_test1111 [24 -8]
# offset_test2222 [24 -8]
# The scan will take 12.5 seconds
# offset_test0000 [24  0]
# offset_test1111 [24  0]
# offset_test2222 [24  0]
# The scan will take 12.5 seconds
# offset_test0000 [24  8]
# offset_test1111 [24  8]
# offset_test2222 [24  8]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 24]
# offset_test1111 [ 8 24]
# offset_test2222 [ 8 24]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 24]
# offset_test1111 [ 0 24]
# offset_test2222 [ 0 24]
# The scan will take 12.5 seconds
# offset_test0000 [-8 24]
# offset_test1111 [-8 24]
# offset_test2222 [-8 24]
# The scan will take 12.5 seconds
# offset_test0000 [-24   8]
# offset_test1111 [-24   8]
# offset_test2222 [-24   8]
# The scan will take 12.5 seconds
# offset_test0000 [-24   0]
# offset_test1111 [-24   0]
# offset_test2222 [-24   0]
# The scan will take 12.5 seconds
# offset_test0000 [-24  -8]
# offset_test1111 [-24  -8]
# offset_test2222 [-24  -8]
# The scan will take 12.5 seconds
# offset_test0000 [ -8 -24]
# offset_test1111 [ -8 -24]
# offset_test2222 [ -8 -24]
# The scan will take 12.5 seconds
# offset_test0000 [  0 -24]
# offset_test1111 [  0 -24]
# offset_test2222 [  0 -24]
# The scan will take 12.5 seconds
# offset_test0000 [  8 -24]
# offset_test1111 [  8 -24]
# offset_test2222 [  8 -24]
# rrrrradius 2 4 8 8 32 32
# The scan will take 12.5 seconds
# offset_test0000 [36 32]
# offset_test1111 [36 32]
# offset_test2222 [36 32]
# The scan will take 12.5 seconds
# offset_test0000 [36 36]
# offset_test1111 [36 36]
# offset_test2222 [36 36]
# The scan will take 12.5 seconds
# offset_test0000 [32 36]
# offset_test1111 [32 36]
# offset_test2222 [32 36]
# The scan will take 12.5 seconds
# offset_test0000 [28 36]
# offset_test1111 [28 36]
# offset_test2222 [28 36]
# The scan will take 12.5 seconds
# offset_test0000 [28 32]
# offset_test1111 [28 32]
# offset_test2222 [28 32]
# The scan will take 12.5 seconds
# offset_test0000 [28 28]
# offset_test1111 [28 28]
# offset_test2222 [28 28]
# The scan will take 12.5 seconds
# offset_test0000 [32 28]
# offset_test1111 [32 28]
# offset_test2222 [32 28]
# The scan will take 12.5 seconds
# offset_test0000 [36 28]
# offset_test1111 [36 28]
# offset_test2222 [36 28]
# rrrrradius 3 2 6 -2 44 28
# The scan will take 12.5 seconds
# offset_test0000 [48 28]
# offset_test1111 [48 28]
# offset_test2222 [48 28]
# The scan will take 12.5 seconds
# offset_test0000 [48 32]
# offset_test1111 [48 32]
# offset_test2222 [48 32]
# The scan will take 12.5 seconds
# offset_test0000 [44 32]
# offset_test1111 [44 32]
# offset_test2222 [44 32]
# The scan will take 12.5 seconds
# offset_test0000 [40 32]
# offset_test1111 [40 32]
# offset_test2222 [40 32]
# The scan will take 12.5 seconds
# offset_test0000 [40 28]
# offset_test1111 [40 28]
# offset_test2222 [40 28]
# The scan will take 12.5 seconds
# offset_test0000 [40 24]
# offset_test1111 [40 24]
# offset_test2222 [40 24]
# The scan will take 12.5 seconds
# offset_test0000 [44 24]
# offset_test1111 [44 24]
# offset_test2222 [44 24]
# The scan will take 12.5 seconds
# offset_test0000 [48 24]
# offset_test1111 [48 24]
# offset_test2222 [48 24]
# rrrrradius 4 2 2 6 48 40
# The scan will take 12.5 seconds
# offset_test0000 [52 40]
# offset_test1111 [52 40]
# offset_test2222 [52 40]
# The scan will take 12.5 seconds
# offset_test0000 [52 44]
# offset_test1111 [52 44]
# offset_test2222 [52 44]
# The scan will take 12.5 seconds
# offset_test0000 [48 44]
# offset_test1111 [48 44]
# offset_test2222 [48 44]
# The scan will take 12.5 seconds
# offset_test0000 [44 44]
# offset_test1111 [44 44]
# offset_test2222 [44 44]
# The scan will take 12.5 seconds
# offset_test0000 [44 40]
# offset_test1111 [44 40]
# offset_test2222 [44 40]
# The scan will take 12.5 seconds
# offset_test0000 [44 36]
# offset_test1111 [44 36]
# offset_test2222 [44 36]
# The scan will take 12.5 seconds
# offset_test0000 [48 36]
# offset_test1111 [48 36]
# offset_test2222 [48 36]
# The scan will take 12.5 seconds
# offset_test0000 [52 36]
# offset_test1111 [52 36]
# offset_test2222 [52 36]
# rrrrradius 5 2 -6 2 36 44
# The scan will take 12.5 seconds
# offset_test0000 [40 44]
# offset_test1111 [40 44]
# offset_test2222 [40 44]
# The scan will take 12.5 seconds
# offset_test0000 [40 48]
# offset_test1111 [40 48]
# offset_test2222 [40 48]
# The scan will take 12.5 seconds
# offset_test0000 [36 48]
# offset_test1111 [36 48]
# offset_test2222 [36 48]
# The scan will take 12.5 seconds
# offset_test0000 [32 48]
# offset_test1111 [32 48]
# offset_test2222 [32 48]
# The scan will take 12.5 seconds
# offset_test0000 [32 44]
# offset_test1111 [32 44]
# offset_test2222 [32 44]
# The scan will take 12.5 seconds
# offset_test0000 [32 40]
# offset_test1111 [32 40]
# offset_test2222 [32 40]
# The scan will take 12.5 seconds
# offset_test0000 [36 40]
# offset_test1111 [36 40]
# offset_test2222 [36 40]
# The scan will take 12.5 seconds
# offset_test0000 [40 40]
# offset_test1111 [40 40]
# offset_test2222 [40 40]
# rrrrradius 6 2 -6 2 24 48
# The scan will take 12.5 seconds
# offset_test0000 [28 48]
# offset_test1111 [28 48]
# offset_test2222 [28 48]
# The scan will take 12.5 seconds
# offset_test0000 [28 52]
# offset_test1111 [28 52]
# offset_test2222 [28 52]
# The scan will take 12.5 seconds
# offset_test0000 [24 52]
# offset_test1111 [24 52]
# offset_test2222 [24 52]
# The scan will take 12.5 seconds
# offset_test0000 [20 52]
# offset_test1111 [20 52]
# offset_test2222 [20 52]
# The scan will take 12.5 seconds
# offset_test0000 [20 48]
# offset_test1111 [20 48]
# offset_test2222 [20 48]
# The scan will take 12.5 seconds
# offset_test0000 [20 44]
# offset_test1111 [20 44]
# offset_test2222 [20 44]
# The scan will take 12.5 seconds
# offset_test0000 [24 44]
# offset_test1111 [24 44]
# offset_test2222 [24 44]
# The scan will take 12.5 seconds
# offset_test0000 [28 44]
# offset_test1111 [28 44]
# offset_test2222 [28 44]
# rrrrradius 7 2 -6 -2 12 44
# The scan will take 12.5 seconds
# offset_test0000 [16 44]
# offset_test1111 [16 44]
# offset_test2222 [16 44]
# The scan will take 12.5 seconds
# offset_test0000 [16 48]
# offset_test1111 [16 48]
# offset_test2222 [16 48]
# The scan will take 12.5 seconds
# offset_test0000 [12 48]
# offset_test1111 [12 48]
# offset_test2222 [12 48]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 48]
# offset_test1111 [ 8 48]
# offset_test2222 [ 8 48]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 44]
# offset_test1111 [ 8 44]
# offset_test2222 [ 8 44]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 40]
# offset_test1111 [ 8 40]
# offset_test2222 [ 8 40]
# The scan will take 12.5 seconds
# offset_test0000 [12 40]
# offset_test1111 [12 40]
# offset_test2222 [12 40]
# The scan will take 12.5 seconds
# offset_test0000 [16 40]
# offset_test1111 [16 40]
# offset_test2222 [16 40]
# rrrrradius 8 2 -6 2 0 48
# The scan will take 12.5 seconds
# offset_test0000 [ 4 48]
# offset_test1111 [ 4 48]
# offset_test2222 [ 4 48]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 52]
# offset_test1111 [ 4 52]
# offset_test2222 [ 4 52]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 52]
# offset_test1111 [ 0 52]
# offset_test2222 [ 0 52]
# The scan will take 12.5 seconds
# offset_test0000 [-4 52]
# offset_test1111 [-4 52]
# offset_test2222 [-4 52]
# The scan will take 12.5 seconds
# offset_test0000 [-4 48]
# offset_test1111 [-4 48]
# offset_test2222 [-4 48]
# The scan will take 12.5 seconds
# offset_test0000 [-4 44]
# offset_test1111 [-4 44]
# offset_test2222 [-4 44]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 44]
# offset_test1111 [ 0 44]
# offset_test2222 [ 0 44]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 44]
# offset_test1111 [ 4 44]
# offset_test2222 [ 4 44]
# rrrrradius 9 2 -6 -2 -12 44
# The scan will take 12.5 seconds
# offset_test0000 [-8 44]
# offset_test1111 [-8 44]
# offset_test2222 [-8 44]
# The scan will take 12.5 seconds
# offset_test0000 [-8 48]
# offset_test1111 [-8 48]
# offset_test2222 [-8 48]
# The scan will take 12.5 seconds
# offset_test0000 [-12  48]
# offset_test1111 [-12  48]
# offset_test2222 [-12  48]
# The scan will take 12.5 seconds
# offset_test0000 [-16  48]
# offset_test1111 [-16  48]
# offset_test2222 [-16  48]
# The scan will take 12.5 seconds
# offset_test0000 [-16  44]
# offset_test1111 [-16  44]
# offset_test2222 [-16  44]
# The scan will take 12.5 seconds
# offset_test0000 [-16  40]
# offset_test1111 [-16  40]
# offset_test2222 [-16  40]
# The scan will take 12.5 seconds
# offset_test0000 [-12  40]
# offset_test1111 [-12  40]
# offset_test2222 [-12  40]
# The scan will take 12.5 seconds
# offset_test0000 [-8 40]
# offset_test1111 [-8 40]
# offset_test2222 [-8 40]
# rrrrradius 10 2 -6 2 -24 48
# The scan will take 12.5 seconds
# offset_test0000 [-20  48]
# offset_test1111 [-20  48]
# offset_test2222 [-20  48]
# The scan will take 12.5 seconds
# offset_test0000 [-20  52]
# offset_test1111 [-20  52]
# offset_test2222 [-20  52]
# The scan will take 12.5 seconds
# offset_test0000 [-24  52]
# offset_test1111 [-24  52]
# offset_test2222 [-24  52]
# The scan will take 12.5 seconds
# offset_test0000 [-28  52]
# offset_test1111 [-28  52]
# offset_test2222 [-28  52]
# The scan will take 12.5 seconds
# offset_test0000 [-28  48]
# offset_test1111 [-28  48]
# offset_test2222 [-28  48]
# The scan will take 12.5 seconds
# offset_test0000 [-28  44]
# offset_test1111 [-28  44]
# offset_test2222 [-28  44]
# The scan will take 12.5 seconds
# offset_test0000 [-24  44]
# offset_test1111 [-24  44]
# offset_test2222 [-24  44]
# The scan will take 12.5 seconds
# offset_test0000 [-20  44]
# offset_test1111 [-20  44]
# offset_test2222 [-20  44]
# rrrrradius 11 2 -6 -2 -36 44
# The scan will take 12.5 seconds
# offset_test0000 [-32  44]
# offset_test1111 [-32  44]
# offset_test2222 [-32  44]
# The scan will take 12.5 seconds
# offset_test0000 [-32  48]
# offset_test1111 [-32  48]
# offset_test2222 [-32  48]
# The scan will take 12.5 seconds
# offset_test0000 [-36  48]
# offset_test1111 [-36  48]
# offset_test2222 [-36  48]
# The scan will take 12.5 seconds
# offset_test0000 [-40  48]
# offset_test1111 [-40  48]
# offset_test2222 [-40  48]
# The scan will take 12.5 seconds
# offset_test0000 [-40  44]
# offset_test1111 [-40  44]
# offset_test2222 [-40  44]
# The scan will take 12.5 seconds
# offset_test0000 [-40  40]
# offset_test1111 [-40  40]
# offset_test2222 [-40  40]
# The scan will take 12.5 seconds
# offset_test0000 [-36  40]
# offset_test1111 [-36  40]
# offset_test2222 [-36  40]
# The scan will take 12.5 seconds
# offset_test0000 [-32  40]
# offset_test1111 [-32  40]
# offset_test2222 [-32  40]
# rrrrradius 12 2 -6 2 -48 48
# The scan will take 12.5 seconds
# offset_test0000 [-44  48]
# offset_test1111 [-44  48]
# offset_test2222 [-44  48]
# The scan will take 12.5 seconds
# offset_test0000 [-44  52]
# offset_test1111 [-44  52]
# offset_test2222 [-44  52]
# The scan will take 12.5 seconds
# offset_test0000 [-48  52]
# offset_test1111 [-48  52]
# offset_test2222 [-48  52]
# The scan will take 12.5 seconds
# offset_test0000 [-52  52]
# offset_test1111 [-52  52]
# offset_test2222 [-52  52]
# The scan will take 12.5 seconds
# offset_test0000 [-52  48]
# offset_test1111 [-52  48]
# offset_test2222 [-52  48]
# The scan will take 12.5 seconds
# offset_test0000 [-52  44]
# offset_test1111 [-52  44]
# offset_test2222 [-52  44]
# The scan will take 12.5 seconds
# offset_test0000 [-48  44]
# offset_test1111 [-48  44]
# offset_test2222 [-48  44]
# The scan will take 12.5 seconds
# offset_test0000 [-44  44]
# offset_test1111 [-44  44]
# offset_test2222 [-44  44]
# rrrrradius 13 2 0 -8 -48 32
# The scan will take 12.5 seconds
# offset_test0000 [-44  32]
# offset_test1111 [-44  32]
# offset_test2222 [-44  32]
# The scan will take 12.5 seconds
# offset_test0000 [-44  36]
# offset_test1111 [-44  36]
# offset_test2222 [-44  36]
# The scan will take 12.5 seconds
# offset_test0000 [-48  36]
# offset_test1111 [-48  36]
# offset_test2222 [-48  36]
# The scan will take 12.5 seconds
# offset_test0000 [-52  36]
# offset_test1111 [-52  36]
# offset_test2222 [-52  36]
# The scan will take 12.5 seconds
# offset_test0000 [-52  32]
# offset_test1111 [-52  32]
# offset_test2222 [-52  32]
# The scan will take 12.5 seconds
# offset_test0000 [-52  28]
# offset_test1111 [-52  28]
# offset_test2222 [-52  28]
# The scan will take 12.5 seconds
# offset_test0000 [-48  28]
# offset_test1111 [-48  28]
# offset_test2222 [-48  28]
# The scan will take 12.5 seconds
# offset_test0000 [-44  28]
# offset_test1111 [-44  28]
# offset_test2222 [-44  28]
# rrrrradius 14 2 6 -2 -36 28
# The scan will take 12.5 seconds
# offset_test0000 [-32  28]
# offset_test1111 [-32  28]
# offset_test2222 [-32  28]
# The scan will take 12.5 seconds
# offset_test0000 [-32  32]
# offset_test1111 [-32  32]
# offset_test2222 [-32  32]
# The scan will take 12.5 seconds
# offset_test0000 [-36  32]
# offset_test1111 [-36  32]
# offset_test2222 [-36  32]
# The scan will take 12.5 seconds
# offset_test0000 [-40  32]
# offset_test1111 [-40  32]
# offset_test2222 [-40  32]
# The scan will take 12.5 seconds
# offset_test0000 [-40  28]
# offset_test1111 [-40  28]
# offset_test2222 [-40  28]
# The scan will take 12.5 seconds
# offset_test0000 [-40  24]
# offset_test1111 [-40  24]
# offset_test2222 [-40  24]
# The scan will take 12.5 seconds
# offset_test0000 [-36  24]
# offset_test1111 [-36  24]
# offset_test2222 [-36  24]
# The scan will take 12.5 seconds
# offset_test0000 [-32  24]
# offset_test1111 [-32  24]
# offset_test2222 [-32  24]
# rrrrradius 15 2 6 -2 -24 24
# The scan will take 12.5 seconds
# offset_test0000 [-20  24]
# offset_test1111 [-20  24]
# offset_test2222 [-20  24]
# The scan will take 12.5 seconds
# offset_test0000 [-20  28]
# offset_test1111 [-20  28]
# offset_test2222 [-20  28]
# The scan will take 12.5 seconds
# offset_test0000 [-24  28]
# offset_test1111 [-24  28]
# offset_test2222 [-24  28]
# The scan will take 12.5 seconds
# offset_test0000 [-28  28]
# offset_test1111 [-28  28]
# offset_test2222 [-28  28]
# The scan will take 12.5 seconds
# offset_test0000 [-28  24]
# offset_test1111 [-28  24]
# offset_test2222 [-28  24]
# The scan will take 12.5 seconds
# offset_test0000 [-28  20]
# offset_test1111 [-28  20]
# offset_test2222 [-28  20]
# The scan will take 12.5 seconds
# offset_test0000 [-24  20]
# offset_test1111 [-24  20]
# offset_test2222 [-24  20]
# The scan will take 12.5 seconds
# offset_test0000 [-20  20]
# offset_test1111 [-20  20]
# offset_test2222 [-20  20]
# rrrrradius 16 2 6 -2 -12 20
# The scan will take 12.5 seconds
# offset_test0000 [-8 20]
# offset_test1111 [-8 20]
# offset_test2222 [-8 20]
# The scan will take 12.5 seconds
# offset_test0000 [-8 24]
# offset_test1111 [-8 24]
# offset_test2222 [-8 24]
# The scan will take 12.5 seconds
# offset_test0000 [-12  24]
# offset_test1111 [-12  24]
# offset_test2222 [-12  24]
# The scan will take 12.5 seconds
# offset_test0000 [-16  24]
# offset_test1111 [-16  24]
# offset_test2222 [-16  24]
# The scan will take 12.5 seconds
# offset_test0000 [-16  20]
# offset_test1111 [-16  20]
# offset_test2222 [-16  20]
# The scan will take 12.5 seconds
# offset_test0000 [-16  16]
# offset_test1111 [-16  16]
# offset_test2222 [-16  16]
# The scan will take 12.5 seconds
# offset_test0000 [-12  16]
# offset_test1111 [-12  16]
# offset_test2222 [-12  16]
# The scan will take 12.5 seconds
# offset_test0000 [-8 16]
# offset_test1111 [-8 16]
# offset_test2222 [-8 16]
# rrrrradius 17 2 6 -2 0 16
# The scan will take 12.5 seconds
# offset_test0000 [ 4 16]
# offset_test1111 [ 4 16]
# offset_test2222 [ 4 16]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 20]
# offset_test1111 [ 4 20]
# offset_test2222 [ 4 20]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 20]
# offset_test1111 [ 0 20]
# offset_test2222 [ 0 20]
# The scan will take 12.5 seconds
# offset_test0000 [-4 20]
# offset_test1111 [-4 20]
# offset_test2222 [-4 20]
# The scan will take 12.5 seconds
# offset_test0000 [-4 16]
# offset_test1111 [-4 16]
# offset_test2222 [-4 16]
# The scan will take 12.5 seconds
# offset_test0000 [-4 12]
# offset_test1111 [-4 12]
# offset_test2222 [-4 12]
# The scan will take 12.5 seconds
# offset_test0000 [ 0 12]
# offset_test1111 [ 0 12]
# offset_test2222 [ 0 12]
# The scan will take 12.5 seconds
# offset_test0000 [ 4 12]
# offset_test1111 [ 4 12]
# offset_test2222 [ 4 12]
# rrrrradius 18 2 6 -2 12 12
# The scan will take 12.5 seconds
# offset_test0000 [16 12]
# offset_test1111 [16 12]
# offset_test2222 [16 12]
# The scan will take 12.5 seconds
# offset_test0000 [16 16]
# offset_test1111 [16 16]
# offset_test2222 [16 16]
# The scan will take 12.5 seconds
# offset_test0000 [12 16]
# offset_test1111 [12 16]
# offset_test2222 [12 16]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 16]
# offset_test1111 [ 8 16]
# offset_test2222 [ 8 16]
# The scan will take 12.5 seconds
# offset_test0000 [ 8 12]
# offset_test1111 [ 8 12]
# offset_test2222 [ 8 12]
# The scan will take 12.5 seconds
# offset_test0000 [8 8]
# offset_test1111 [8 8]
# offset_test2222 [8 8]
# The scan will take 12.5 seconds
# offset_test0000 [12  8]
# offset_test1111 [12  8]
# offset_test2222 [12  8]
# The scan will take 12.5 seconds
# offset_test0000 [16  8]
# offset_test1111 [16  8]
# offset_test2222 [16  8]
# rrrrradius 19 2 6 -2 24 8

# %%
atom_forward = blob_detection(info[img_forward])[0]
atom_backward = blob_detection(info[img_backward])[0]

max_num_dect = 10
done_dect_atom = False
for i_dect in range(max_num_dect):

    if len(atom_forward)>0 and len(atom_backward)>0:
        done_dect_atom = True
        continue
    else:
        # looking for new area
        # TODO spiral path planing to choose tip position
        ID= compositionID()
        x=np.array([abc[i][0] for i in range(len(ID))])
        y=np.array([abc[i][1] for i in range(len(ID))])
        x=x-x.min()
        y=y-y.min()
        for i in range(len(ID)):
            
        forbiden_area = 
        tip_x_new, tip_y_new = New_tippos(tip_x, tip_y, forbiden:area) 
        
# TODO if not done_dect_atom after max_num_dect times looking for
# Out:
# 80

# %%
def scan_trajectory(abc, initial_offset_nm=np.array([-50, 90])):
    images=[]
    for i in range(0,len(abc)):
        env.createc_controller.offset_nm=np.array([initial_offset_nm[0]+80/16*abc[i][0],initial_offset_nm[0]+80/16*abc[i][1]])
        env.createc_controller.im_size_nm = 5
        image=env.createc_controller.scan_image()
        env.createc_controller.stm.quicksave()
        # images.append(image)
        # plt.imshow(image[0])
        # plt.show()
        # print(image)
        print(env.createc_controller.get_offset_nm()[0],env.createc_controller.get_offset_nm()[1])
        # plt.scatter(env.createc_controller.get_offset_nm()[0],env.createc_controller.get_offset_nm()[1])
        plt.scatter(env.createc_controller.offset_nm[0],env.createc_controller.offset_nm[1])
        # plt.plot(env.createc_controller.offset_nm[0],env.createc_controller.offset_nm[1])

        
        plt.gca().add_patch(patches.Rectangle((initial_offset_nm[0]+80/16*abc[i][0]-2.5, initial_offset_nm[1]+80/16*abc[i][1]), 5, 5, fill=False, edgecolor='grey', lw=2))
        # offset_nm=env.createc_controller.offset_nm+5
    plt.plot([initial_offset_nm[0]+80/16*i[0] for i in abc], [initial_offset_nm[1]+80/16*i[1] for i in abc])

# %%
createc_controller.stm.setparam('Delta X [DAC]', 118)
createc_controller.stm.setparam('BiasVolt.[mV]', 50)
createc_controller.stm.setparam('ZPiezoconst', 8.43)
createc_controller.stm.setparam('SetPoint', 5.00E-12)
createc_controller.stm.setparam('FBLogIset', 50)
env.createc_controller.stm.setparam('TipForm_Volt', -3) # Set the bias voltage for the atom manipulation(unit V)
env.createc_controller.stm.setparam('TipForm_Z', 0.0) # Set the z position for the atom manipulation(unit angstrom)
env.createc_controller.stm.setparam('Tip_Delay', 0.4915) # Set the delay time for the atom manipulation(unit s)
env.createc_controller.stm.setparam('Tip_Latddx', 833) # Set the lateral ddx for the atom manipulation(unit angstrom/ms^2)
env.createc_controller.stm.setparam('Tip_LatDelay', 20) # Set the lateral delay for the atom manipulation(unit ms)
env.createc_controller.stm.setparam('Tip_Gain', 6) # Set the gain for the atom manipulation(unit 1)
env.createc_controller.stm.setparam('TipForm_Zoffset', 0.0) # Set the z offset for the atom manipulation(unit angstrom)

# %% [markdown]
# ### Create a sac_agent object

# %%
#TODO
batch_size= 64 #Set minibatch size
LEARNING_RATE = 0.0003 #Set learning rate

#Set the action space range
ACTION_SPACE = namedtuple('ACTION_SPACE', ['high', 'low'])
action_space = ACTION_SPACE(high = torch.tensor([1,1,1,1,1,1]), low = torch.tensor([-1,-1,-1,-1,1/3,1/2]))

#Initialize the soft actor-critic agent
alpha = 1.0
agent = sac_agent(num_inputs = 4, num_actions = 6, action_space = action_space, device=device, hidden_size=256, lr=LEARNING_RATE,
                 gamma=0.9, tau=0.005, alpha=alpha)

# %% [markdown]
# ### Create a HerReplayMemory object
# Here we use the hindsight experience replay with the 'future' strategy to sample goals

# %%
#TODO
replay_size=1000000 #Set memory size

memory = HerReplayMemory(replay_size, env, strategy = 'future')

# %%
memory.n_sampled_goal
# Out:
# 2

# %% [markdown]
# ### Create a Episode_Memory object
# The episode memory class is used to store all the relavant information in each training episode, including the STM images, state, action, reward, etc.

# %%
episode_memory = Episode_Memory()
#TODO
#Set the folder name to store training data and neural network weight
folder_name =  'C:/Users/wun2/github/Atom_manipulation_with_RL/test_nian'

# %% [markdown]
# ### Set the hyperparameters for Emphasize Recent Experience replay

# %%
c_k_min = 500
eta = 0.994
max_ep_len = max_len

# %% [markdown]
# ### Create empty lists for logging performances

# %%
episode_rewards, alphas, precisions, episode_lengths = [], [], [], []
avg_episode_rewards, avg_alphas, avg_precisions, avg_episode_lengths = [], [], [], []

# %%
max_steps = 5
num_episodes = 50
episode_start = 0

# %%
done_dect_atom=False

# %%
# find a section to condition tip
start_crash_hole=0
approach_z=2

def tip_cond_area(center_x=0, center_y=0, approach_area_length=800, cond_area_length=200, margin=20):
    cond_area_center_x, cond_area_center_y=center_x-approach_area_length+cond_area_length+margin, center_y-approach_area_length+cond_area_center_y+margin
    return cond_area_center_x, cond_area_center_y, cond_area_length

env.default_max_radius_cellsize(cellsize=20, max_radius=200)
points=env.computeLocationIDs()
cond_area_center_x, cond_area_center_y, cond_area_length=tip_cond_area()

env.createc_controller.ramp_bias_mV(-1.2)
env.createc_controller.tip_form(approach_z, cond_area_center_x+points[start_crash_hole][0]*cellsize,cond_area_center_y+points[start_crash_hole][1]*cellsize)
print(env.createc_controller.im_size_nm)
start_crash_hole=start_crash_hole

# %%
start_x = 0
start_y = 0
tip_x = 0
tip_y = 0
check_similarity=None
check_similarity.append([tip_x, tip_y])
radius = 35
upper_limit_move=400
env.max_radius=150

image_forward = info['img_info']['img_forward']
image_backward =info['img_info']['img_backward']


# dectect atoms
isAtom = False



# debris
debris_thres = 6
DebresCounter = 0
noDebris = False



# Crash dectected
crash_thres = 1e-25 
approach_z = 4
noCrash = False


while not isAtom or not noDebris or not noCrash:
    
    # detect atoms
    atom_forward = blob_detection(info[img_forward])[0]

    if len(atom_forward)>0:
        isAtom = True

    # detect debris
    noDebris =  ((np.max(image_forward) - np.min(image_forward)) < debris_thres) 
    
    # dectect crash
    noCrash = (np.max(img_forward)-np.min(img_forward) )< crash_thres and (np.mean(img_forward)>0)
    
    if isAtom and noDebris and noCrash:
        continue
        
        
        
    else:
        tip_x, tip_y=env.GetNextGoodClosest(tip_x, tip_y, initial_x=start_x, initial_y=start_y, forbiden_radius=radius, upper_limit_move=upper_limit_move,approach_limit=[-180, 180, -180, 180],check_similarity=check_similarity) 
        if tip_x==None:
            tip_x, tip_y=check_similarity[-1][0], check_similarity[-1][1]
            image=env.set_newtip_pos(tip_x, tip_y)
            image_forward, image_backward =image[0], image[1]
            radius=radius*2
            env.max_radius=env.max_radius*2
            upper_limit_move=upper_limit_move+20000
        else:
            radius=35
            upper_limit_move=400
            env.max_radius=150
                
    
            
            
    check_similarity.append([tip_x, tip_y])        
    if radius>280:
        print('there is no section satisfying the demand within radius of 280 nm')
        break

# %%
# dectect atoms
tip_x=0
tip_y=0
radius=35
max_num_dect = 10
check_similarity=[]
check_similarity.append([tip_x, tip_y])
upper_limit_move=400
done_dect_atom = False
for i_dect in range(max_num_dect):
    atom_forward = blob_detection(info[img_forward])[0]
    atom_backward = blob_detection(info[img_backward])[0]
    if len(atom_forward)>0 and len(atom_backward)>0:
        done_dect_atom = True
        continue
        plt.text(new_x_a, new_y_a+5, epoch)
    #     env.switch_approach_area()
    #     env.ForbiddenArea(forbiden_radius=radius)
        plt.gca().add_patch(patches.Circle((tip_x, tip_y), radius, fill=False))
        tip_x, tip_y=env.GetNextGoodClosest(tip_x, tip_y, initial_x=0, initial_y=0, forbiden_radius=radius, upper_limit_move=upper_limit_move,approach_limit=[-180, 180, -180, 180],check_similarity=check_similarity) 
        print(tip_x, tip_y, radius)  

        env.createc_controller.offset_nm=np.array([tip_x, tip_y])
        env.createc_controller.im_size_nm = 5
        image=env.createc_controller.scan_image()
        env.createc_controller.stm.quicksave()
        atom_forward, atom_backward =image[0], image[1]
        
        
            
        if len(atom_forward)>0 and len(atom_backward)>0:
            done_dect_atom = True
            
        else:
            tip_x, tip_y=check_similarity[-1][0], check_similarity[-1][1]
#             plt.gca().add_patch(patches.Circle((tip_x, tip_y), radius, fill=False, color='yellow'))
            radius=radius*2
            env.max_radius=300
            upper_limit_move=upper_limit_move+20000
            check_similarity.append([tip_x, tip_y])


        
# TODO if not done_dect_atom after max_num_dect times looking for

# debris
#  threshold for the difference between max and min values in the image. If this is exceeded, the region is considered to contain excessive roughness.
start_x = 0
start_y = 0
tip_x = 0
tip_y = 0
debris_thres = 6
DebresCounter = 0
noDebris = False
image_forward = info['img_info']['img_forward']
radius = 10
check_similarity=None

while not noDebris:
      noDebris =  ((np.max(image_forward) - np.min(image_forward)) < debris_thres)      
      if not noDebris:
        tip_x, tip_y=env.GetNextGoodClosest(tip_x, tip_y, initial_x=start_x, initial_y=start_y, forbiden_radius=radius, upper_limit_move=upper_limit_move,approach_limit=[-180, 180, -180, 180],check_similarity=check_similarity) 
        image=env.set_newtip_pos(tip_x, tip_y)
        image_forward, image_backward =image[0], image[1]
        radius=radius*2
        env.max_radius=300
        upper_limit_move=upper_limit_move+20000
        check_similarity.append([tip_x, tip_y])
        
        
# Crash dectected
crash_thres = 1e-25 
noCrash = False
approach_z = 4
while not noCrash:
    noCrash = (np.max(img_forward)-np.min(img_forward) )< crash_thres and (np.mean(img_forward)>0)
    
    if not noCrash:
        tip_x, tip_y=env.GetNextGoodClosest(tip_x, tip_y, initial_x=start_x, initial_y=start_y, forbiden_radius=radius, upper_limit_move=upper_limit_move,approach_limit=[-180, 180, -180, 180],check_similarity=check_similarity) 
        tip_z = env.createc_controller.set_Z_approach(approach_z)
        image=env.set_newtip_pos(tip_x, tip_y)
        image_forward, image_backward =image[0], image[1]
        radius=radius*2
        env.max_radius=300
        upper_limit_move=upper_limit_move+20000
        check_similarity.append([tip_x, tip_y])

# %% [markdown]
# # detect atoms or not

# %%
tip_x=0
tip_y=0
radius=35
max_num_dect = 10
check_similarity=[]
check_similarity.append([tip_x, tip_y])
upper_limit_move=400
done_dect_atom = False
for i_dect in range(max_num_dect):
    atom_forward = blob_detection(info[img_forward])[0]
    atom_backward = blob_detection(info[img_backward])[0]
    if len(atom_forward)>0 and len(atom_backward)>0:
        done_dect_atom = True
        continue
        plt.text(new_x_a, new_y_a+5, epoch)
    #     env.switch_approach_area()
    #     env.ForbiddenArea(forbiden_radius=radius)
        plt.gca().add_patch(patches.Circle((tip_x, tip_y), radius, fill=False))
        tip_x, tip_y=env.GetNextGoodClosest(tip_x, tip_y, initial_x=0, initial_y=0, forbiden_radius=radius, upper_limit_move=upper_limit_move,approach_limit=[-180, 180, -180, 180],check_similarity=check_similarity) 
        print(tip_x, tip_y, radius)  

        env.createc_controller.offset_nm=np.array([tip_x, tip_y])
        env.createc_controller.im_size_nm = 5
        image=env.createc_controller.scan_image()
        env.createc_controller.stm.quicksave()
        atom_forward, atom_backward =image[0], image[1]
        
        
            
        if len(atom_forward)>0 and len(atom_backward)>0:
            done_dect_atom = True
            
        else:
            tip_x, tip_y=check_similarity[-1][0], check_similarity[-1][1]
#             plt.gca().add_patch(patches.Circle((tip_x, tip_y), radius, fill=False, color='yellow'))
            radius=radius*2
            env.max_radius=300
            upper_limit_move=upper_limit_move+20000
            check_similarity.append([tip_x, tip_y])


        
# TODO if not done_dect_atom after max_num_dect times looking for

# %% [markdown]
# # detect atoms or not

# %%
def New_tippos(tip_x, tip_y, im_size_nm=5):
    env.createc_controller.offset_nm=np.array([tip_x, tip_y])
    env.createc_controller.im_size_nm = im_size_nm
    image=env.createc_controller.scan_image()
    env.createc_controller.stm.quicksave()
    return createc_controller.set_xy_nm(np.array([tip_x, tip_y]))

# %%
atom_forward = blob_detection(info[img_forward])[0]
atom_backward = blob_detection(info[img_backward])[0]

max_num_dect = 10
done_dect_atom = False
for i_dect in range(max_num_dect):

    if len(atom_forward)>0 and len(atom_backward)>0:
        done_dect_atom = True
        continue
    else:
        # looking for new area
        # TODO spiral path planing to choose tip position
        ID= compositionID(tip_x, tip_y)
        forbiden_area = 
        tip_x_new, tip_y_new = New_tippos(tip_x, tip_y, forbiden:area) 
        
# TODO if not done_dect_atom after max_num_dect times looking for

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
def FindEmptySquareArea(mat : np.array, ZERO=0) -> tuple:
    """_summary_

    Args:
        mat (np.array): pixel matrix
        ZERO (int, optional): _description_. Defaults to 0.

    Returns:
        length: the length of the square
        start_x: the x position of the start of the square
        start_y: the y position of the start of the square
    """    
    #Find the largest square of ZERO's in the matrix `mat`.
    #Source: https://stackoverflow.com/a/1726667
    
    # Extract array shape
    nrows, ncols = mat.shape
    
    # Check for null array / empty matrix or rows
    if not (nrows and ncols):
        return 0
    
    # Initiate null array based on row and column sizes
    counts = np.zeros((nrows, ncols))
    
    # For each row
    for i in reversed(range(nrows)):
        # The matrix must be rectangular (actually square)
        assert len(mat[i]) == ncols
        
        # For each element in the row
        for j in reversed(range(ncols)):
            
            # If the element is zero, check around it
            if mat[i][j] == ZERO:
                counts[i][j] = (1 + min(
                    counts[i][j+1],   # east
                    counts[i+1][j],   # south
                    counts[i+1][j+1]  # south-east
                    )) if i < (nrows - 1) and j < (ncols - 1) else 1  # edges
    length = -1
    start_x = -1
    start_y = -1
    for row in range(len(counts)):
        for col in range(len(counts[row])):
            if counts[row, col] > length:
                length = counts[row, col]
                start_x = row
                start_y = col

    return length, start_x, start_y


def FindEmptySquareAreaPosition(img : np.array) -> tuple:
    """_summary_

    Args:
        mat (np.array): pixel matrix
        ZERO (int, optional): _description_. Defaults to 0.

    Returns:
        length: the length of the square
        start_x: the x position of the start of the square
        start_y: the y position of the start of the square
    """   
    # Returns the Y,X center of the largest empty square in an image and size.
    # Prints a nice reference image for sanity check.
    length, start_x, start_y = FindEmptySquareArea(img, 0)
    
    # Calculate the center
    start_x = start_x+length/2
    start_y = start_y+length/2

    
    # Visual output of the square
    # Normalize the image
    img = (img-img.min())/(img.max()-img.min())
    img *= 255
    start_x = int(start_x)
    start_y = int(start_y)


    # Draw a box around the edge of the square
    img[int(start_x),int(start_y)]=255
    img[int(start_x-1),int(start_y-1)]=255
    img[int(start_x-1),int(start_y+1)]=255
    img[int(start_x+1),int(start_y-1)]=255
    img[int(start_x+1),int(start_y+1)]=255
    for i in range(int(length)):
        img[int(start_x+i-length/2),int(start_y-length/2)] = 255
        img[int(start_x+i-length/2),int(start_y+length-length/2)] = 255
        img[int(start_x-length/2),int(start_y+i-length/2)] = 255
        img[int(start_x+length-length/2),int(start_y+i-length/2)] = 255
        
    # Print the image (quick reference)
    plt.imshow(img, cmap = "gray");
    return length, start_x, start_y

# %%
env.createc_controller.get_len_nm()
# Out:
# 19.843359375

# %%
a=np.random.randn(128,128)

# %%
a[10:30,15:40]=0
a[50:60,50:60]=0

# %%
 FindEmptySquareArea(a)
# Out:
# (20.0, 10, 15)

# %%
FindEmptySquareAreaPosition(a)
# Out:
# (20.0, 20, 25)

# %% [markdown]
# # debrics

# %%
#  threshold for the difference between max and min values in the image. If this is exceeded, the region is considered to contain excessive roughness.
start_x = 0
start_y = 0
tip_x = 0
tip_y = 0
debris_thres = 6
DebresCounter = 0
noDebris = False
image_forward = info['img_info']['img_forward']
radius = 10
check_similarity=None

while not noDebris:
      noDebris =  ((np.max(image_forward) - np.min(image_forward)) < debris_thres)      
      if not noDebris:
        tip_x, tip_y=env.GetNextGoodClosest(tip_x, tip_y, initial_x=start_x, initial_y=start_y, forbiden_radius=radius, upper_limit_move=upper_limit_move,approach_limit=[-180, 180, -180, 180],check_similarity=check_similarity) 
        image=env.set_newtip_pos(tip_x, tip_y)
        image_forward, image_backward =image[0], image[1]
        radius=radius*2
        env.max_radius=300
        upper_limit_move=upper_limit_move+20000
        check_similarity.append([tip_x, tip_y])

# %% [markdown]
# # Lost probe_molecule contact and crashed

# %%
# Crash dectected
crash_thres = 1e-25 
noCrash = False
approach_z = 4
while not noCrash:
    noCrash = (np.max(img_forward)-np.min(img_forward) )< crash_thres and (np.mean(img_forward)>0)
    
    if not noCrash:
        tip_x, tip_y=env.GetNextGoodClosest(tip_x, tip_y, initial_x=start_x, initial_y=start_y, forbiden_radius=radius, upper_limit_move=upper_limit_move,approach_limit=[-180, 180, -180, 180],check_similarity=check_similarity) 
        tip_z = env.createc_controller.set_Z_approach(approach_z)
        image=env.set_newtip_pos(tip_x, tip_y)
        image_forward, image_backward =image[0], image[1]
        radius=radius*2
        env.max_radius=300
        upper_limit_move=upper_limit_move+20000
        check_similarity.append([tip_x, tip_y])

# %%
env.createc_controller.set_Z_approach(4)

# %%
env.createc_controller.scan_image()
# Out:
# The scan will take 12.5 seconds
# offset_test0000 [ 23.99753723 -23.99753723]
# offset_test1111 [ 23.99753723 -23.99753723]
# offset_test2222 [ 23.99753723 -23.99753723]
# (array([[-2.01714039, -2.01696873, -2.01708841, ..., -2.02151728,
#          -2.02146792, -2.02165771],
#         [-2.02180839, -2.02207851, -2.02216959, ..., -2.02135611,
#          -2.02143407, -2.02120018],
#         [-2.0213275 , -2.02120543, -2.02127552, ..., -2.02428007,
#          -2.02426982, -2.02433729],
#         ...,
#         [-2.02020478, -2.02010083, -2.02011633, ..., -2.02194095,
#          -2.0220058 , -2.02209949],
#         [-2.02213073, -2.02222681, -2.02220082, ..., -2.02358365,
#          -2.02343535, -2.02330303],
#         [-2.02324319, -2.02307653, -2.02307415, ..., -2.02321959,
#          -2.02339125, -2.0235889 ]]),
#  array([[-2.02011895, -2.02010083, -2.02044892, ..., -2.01993179,
#          -2.02000189, -2.01992655],
#         [-2.02000189, -2.02010846, -2.02038145, ..., -2.02390313,
#          -2.02391624, -2.02399158],
#         [-2.02402282, -2.02391624, -2.02373695, ..., -2.02405667,
#          -2.02395511, -2.02376795],
#         ...,
#         [-2.02273369, -2.02253866, -2.02229953, ..., -2.01992416,
#          -2.01957846, -2.01934195],
#         [-2.01923513, -2.0190897 , -2.01938081, ..., -2.02325869,
#          -2.023386  , -2.0231626 ],
#         [-2.02323794, -2.02338076, -2.02332878, ..., -2.02414489,
#          -2.02452707, -2.02487803]]),
#  array([ 23.99753723, -23.99753723]),
#  array([4.96099, 4.96099]))

# %%
env.createc_controller.stm.quicksave()

# %% [markdown]
# # tip condition section

# %%
center_x=0
center_y=0
approach_area_length=800
def tip_cond_area(center_x=0, center_y=0, approach_area_length=800, cond_area_length=200, margin=20):
    cond_area_center_x, cond_area_center_y=center_x-approach_area_length+cond_area_length+margin, center_y-approach_area_length+cond_area_center_y+margin
    return cond_area_center_x, cond_area_center_y, cond_area_length

# %%
env.createc_controller.im_size_nm=5

# %%
env.createc_controller.scan_image()
# Out:
# The scan will take 12.5 seconds
# offset_test0000 [39.9988076 39.9988076]
# offset_test1111 [39.9988076 39.9988076]
# offset_test2222 [39.9988076 39.9988076]
# (array([[-2.01714039, -2.01696873, -2.01708841, ..., -2.02151728,
#          -2.02146792, -2.02165771],
#         [-2.02180839, -2.02207851, -2.02216959, ..., -2.02135611,
#          -2.02143407, -2.02120018],
#         [-2.0213275 , -2.02120543, -2.02127552, ..., -2.02428007,
#          -2.02426982, -2.02433729],
#         ...,
#         [-2.02020478, -2.02010083, -2.02011633, ..., -2.02194095,
#          -2.0220058 , -2.02209949],
#         [-2.02213073, -2.02222681, -2.02220082, ..., -2.02358365,
#          -2.02343535, -2.02330303],
#         [-2.02324319, -2.02307653, -2.02307415, ..., -2.02321959,
#          -2.02339125, -2.0235889 ]]),
#  array([[-2.02011895, -2.02010083, -2.02044892, ..., -2.01993179,
#          -2.02000189, -2.01992655],
#         [-2.02000189, -2.02010846, -2.02038145, ..., -2.02390313,
#          -2.02391624, -2.02399158],
#         [-2.02402282, -2.02391624, -2.02373695, ..., -2.02405667,
#          -2.02395511, -2.02376795],
#         ...,
#         [-2.02273369, -2.02253866, -2.02229953, ..., -2.01992416,
#          -2.01957846, -2.01934195],
#         [-2.01923513, -2.0190897 , -2.01938081, ..., -2.02325869,
#          -2.023386  , -2.0231626 ],
#         [-2.02323794, -2.02338076, -2.02332878, ..., -2.02414489,
#          -2.02452707, -2.02487803]]),
#  array([39.9988076, 39.9988076]),
#  array([4.96099, 4.96099]))

# %%
env.createc_controller.scan_image()
# Out:
# The scan will take 12.5 seconds
# offset_test0000 [39.9988076 39.9988076]
# offset_test1111 [39.9988076 39.9988076]
# offset_test2222 [39.9988076 39.9988076]
# (array([[-2.01714039, -2.01696873, -2.01708841, ..., -2.02151728,
#          -2.02146792, -2.02165771],
#         [-2.02180839, -2.02207851, -2.02216959, ..., -2.02135611,
#          -2.02143407, -2.02120018],
#         [-2.0213275 , -2.02120543, -2.02127552, ..., -2.02428007,
#          -2.02426982, -2.02433729],
#         ...,
#         [-2.02020478, -2.02010083, -2.02011633, ..., -2.02194095,
#          -2.0220058 , -2.02209949],
#         [-2.02213073, -2.02222681, -2.02220082, ..., -2.02358365,
#          -2.02343535, -2.02330303],
#         [-2.02324319, -2.02307653, -2.02307415, ..., -2.02321959,
#          -2.02339125, -2.0235889 ]]),
#  array([[-2.02011895, -2.02010083, -2.02044892, ..., -2.01993179,
#          -2.02000189, -2.01992655],
#         [-2.02000189, -2.02010846, -2.02038145, ..., -2.02390313,
#          -2.02391624, -2.02399158],
#         [-2.02402282, -2.02391624, -2.02373695, ..., -2.02405667,
#          -2.02395511, -2.02376795],
#         ...,
#         [-2.02273369, -2.02253866, -2.02229953, ..., -2.01992416,
#          -2.01957846, -2.01934195],
#         [-2.01923513, -2.0190897 , -2.01938081, ..., -2.02325869,
#          -2.023386  , -2.0231626 ],
#         [-2.02323794, -2.02338076, -2.02332878, ..., -2.02414489,
#          -2.02452707, -2.02487803]]),
#  array([39.9988076, 39.9988076]),
#  array([1.93395, 4.96099]))

# %%
env.createc_controller.get_len_nm()
# Out:
# 4.96083984375

# %%
env.createc_controller.tip_form(0.02, ref_x+i*cellsize, ref_y+j*cellsize)

# %%
env.createc_controller.scan_image()
# Out:
# The scan will take 12.5 seconds
# offset_test0000 [40  0]
# offset_test1111 [40  0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20120\3189140148.py in <module>
# ----> 1 env.createc_controller.scan_image()
#
# ~\github\Atom_manipulation_with_RL_0523\AMRL\Environment\createc_control.py in scan_image(self, DIR_NAME, BASE_NAME, counter, save, speed)
#     114         time.sleep(scan_time -2)
#     115         while True:
# --> 116             time.sleep(2)
#     117             scanstatus = self.stm.scanstatus
#     118             if scanstatus!=2:
#
# KeyboardInterrupt:

# %%
env.createc_controller.stm.getparam('Length x[A]')
# Out:
# '49.6099'

# %%
env.createc_controller.stm.getparam('Length y[A]')
# Out:
# '49.6099'

# %%
env.createc_controller.get_len_nm()
# Out:
# 1.76572265625

# %%
env.createc_controller.im_size_nm
# Out:
# 2

# %%
env.createc_controller.stm.setparam('Length y[A]', 58)

# %%
env.createc_controller.stm.setparam('Length x[A]', 58)

# %%
env.default_max_radius_cellsize(cellsize=20, max_radius=200)
env.computeLocationIDs()
points=env.computeLocationIDs()
all_x=np.array([i[0] for i in points])
all_y=np.array([i[1] for i in points])
ref_x=0
ref_y=0
cellsize=20
start_point=0
approach_z=0
for point in range(start_point, len(points)):
    i=points[point][0]
    j=points[point][1]
    plt.scatter(ref_x+i*cellsize,ref_y+j*cellsize)
    plt.gca().add_patch(patches.Rectangle((ref_x+i*cellsize-10,  ref_y+j*cellsize), 20, 20, fill=True, edgecolor='grey', lw=2))
#     env.tip_form(-1.2, 0.02, ref_x+i*cellsize, ref_y+j*cellsize)
    env.createc_controller.ramp_bias_mV(-1.2)
    env.createc_controller.tip_form(0.02, ref_x+i*cellsize, ref_y+j*cellsize)
    print(env.createc_controller.im_size_nm)
    
    tip_z = env.createc_controller.set_Z_approach(approach_z)
    
    env.set_newtip_pos(ref_x+i*cellsize, ref_y+j*cellsize)
#     env.createc_controller.scan_image()
#     env.createc_controller.stm.quicksave()
    start_point=point
    
plt.plot(ref_x+all_x*cellsize,ref_y+all_y*cellsize)
# Out:
# 5
# The scan will take 12.5 seconds
# offset_test0000 [40  0]
# offset_test1111 [40  0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20120\3922689985.py in <module>
#      21     tip_z = env.createc_controller.set_Z_approach(approach_z)
#      22
# ---> 23     env.set_newtip_pos(ref_x+i*cellsize, ref_y+j*cellsize)
#      24 #     env.createc_controller.scan_image()
#      25 #     env.createc_controller.stm.quicksave()
#
# ~\github\Atom_manipulation_with_RL_0523\AMRL\Environment\Env_new.py in set_newtip_pos(self, tip_x, tip_y, im_size_nm)
#     690         self.createc_controller.offset_nm=np.array([tip_x, tip_y])
#     691         self.createc_controller.im_size_nm = im_size_nm
# --> 692         image=self.createc_controller.scan_image()
#     693         self.createc_controller.stm.quicksave()
#     694         # self.createc_controller.set_xy_nm(np.array([tip_x, tip_y]))
#
# ~\github\Atom_manipulation_with_RL_0523\AMRL\Environment\createc_control.py in scan_image(self, DIR_NAME, BASE_NAME, counter, save, speed)
#     114         time.sleep(scan_time -2)
#     115         while True:
# --> 116             time.sleep(2)
#     117             scanstatus = self.stm.scanstatus
#     118             if scanstatus!=2:
#
# KeyboardInterrupt:

# %% [markdown]
# # Condition probe

# %%
env.createc_controller.stm.setparam('TipForm_Volt', -3) # Set the bias voltage for the atom manipulation(unit V)

env.createc_controller.stm.setparam('TipForm_Z', 0.0) # Set the z position for the atom manipulation(unit angstrom)

env.createc_controller.stm.setparam('Tip_Delay', 0.4915) # Set the delay time for the atom manipulation(unit s)
env.createc_controller.stm.setparam('Tip_Latddx', 833) # Set the lateral ddx for the atom manipulation(unit angstrom/ms^2)
env.createc_controller.stm.setparam('Tip_LatDelay', 20) # Set the lateral delay for the atom manipulation(unit ms)
env.createc_controller.stm.setparam('Tip_Gain', 6) # Set the gain for the atom manipulation(unit 1)
env.createc_controller.stm.setparam('TipForm_Zoffset', 0.0) # Set the z offset for the atom manipulation(unit angstrom)

# %%
tip_condition_actions={'stall': [0, 0],
                      'soft pulse pos':[0, 2.5],
                      'medium pulse pos': [0, 4.0],
                      'soft pulse neg': [0 , -2.5], 
                      'medium pulse neg': [0, -4],
                      'strong pulse neg': [0, -8],
                      'very soft dip': [0, -8],
                      'soft dip 1': [-0.80, 0.02],
                      'soft dip 2': [-1.2, 0.02],
                      'soft dip 3': [-1.8, 0.02],
                      'medium soft': [-2.5, 0.02],
                      'strong dip': [-5.0, 0.02]
                      }

# %%
def tip_form(self, dip_z_nm: float, voltage: float, x_nm: float, y_nm: float) -> None:
    """Perform tip forming
    Parameters
    ----------
    dip_z_nm : float
        Z approach value in A
    voltage : float
        Voltage value in V
    x_nm, y_nm : float
        STM coordinates (nm)
    """
    offset_nm = self.get_offset_nm()
    len_nm = self.get_len_nm()
    self.stm.setparam('BiasVolt.[mV]',Voltage)
    self.ramp_bias_mV(mvoltage)
    preamp_grain = 10**float(self.stm.getparam("Latmangain"))
    self.stm.setparam("LatmanVolt",  mvoltage) #(mV)
#     self.stm.setparam("Latmanlgi", pcurrent*1e-9*preamp_grain) #(pA)
    
    self.set_Z_approach(A)
    args = x_nm, y_nm, None, None, offset_nm, len_nm
    x_pixel, y_pixel, _, _ = self.nm_to_pixel(*args)
    self.stm.btn_tipform(x_pixel, y_pixel)
    self.stm.waitms(50)

# %%
self.ramp_bias_mV(self.scan_mV)
DAC_unit = 2**19
self.stm.setparam('Num.X',self.pixel)
GainX = float(self.stm.getparam("GainX"))
Delta_X = self.get_Delta_X(self.im_size_nm)
self.stm.setparam('Delta X [Dac]',Delta_X)
time.sleep(0.1)
scan_time = self.get_scan_time()
print('The scan will take {0:.1f} seconds'.format(scan_time))
if scan_time > 600:
    approve = input('Scan will take {} minutes, \
        type yes to continue and no to interrupt'.format(scan_time/60))
    if approve == 'no':
        return None, (None, None)
Xpiezoconst = float(self.stm.getparam("Xpiezoconst"))
Ypiezoconst = float(self.stm.getparam("Ypiezoconst"))
xV = GainX*self.offset_nm[0]/Xpiezoconst
yV = GainX*self.offset_nm[1]/Ypiezoconst

# %%
env.createc_controller.stm.getparam("GainX")
env.createc_controller.stm.getparam("Xpiezoconst")

# %%
env.createc_controller.stm.setxyoffvolt(xV, yV)

# %%
env.createc_controller.stm.getparam("Ypiezoconst")

# %%
env.createc_controller.offset_nm=np.array([-15, 33])

# %%
env.createc_controller.im_size_nm

# %%
env.createc_controller.scan_image()

# %%
env.createc_controller.get_offset_nm()

# %%
state, info = env.reset(update_conv_net=False)

# %%
num_no_done = 0
episode_start=0
max_episode = 10
num_episodes=50
for i_episode in range(episode_start,episode_start+num_episodes):
    print('Episode:', i_episode)
    episode_reward, episode_steps = 0, 0
    done = False
    print('offffset0000',env.offset_nm)
    state, info = env.reset(update_conv_net=False)
    print(state, info)
    
 # detect atoms   

#  no debris

# crash or no probe-atom contact
    
    
    show_reset(env.img_info, env.atom_start_absolute_nm, env.destination_absolute_nm,
               env.template_nm, env.template_wh)
    episode_memory.update_memory_reset(env.img_info, i_episode, info)
    print('offffset1111',env.offset_nm)
    


    for step in range(max_steps):
        action = agent.select_action(state)
        old_atom_nm = env.atom_absolute_nm
        print('offffset2222',env.offset_nm)
        next_state, reward, done, info = env.step(action)
        print('offffset3333',env.offset_nm)
        episode_steps+=1
        episode_reward+=reward
        mask = float(not done)
        memory.push(state,action,reward,next_state,mask)
        episode_memory.update_memory_step(state, action, next_state, reward, done, info)
        print(info)
        show_step(env.img_info, info['start_nm']+old_atom_nm, info['end_nm']+old_atom_nm,
                    env.atom_absolute_nm, env.atom_start_absolute_nm, 
                    env.destination_absolute_nm, action[4]*env.max_mvolt, 
                    action[5]*env.max_pcurrent_to_mvolt_ratio*action[4]*env.max_mvolt, 
                    env.template_nm, env.template_wh)
        print('step:', step,'reward', reward, 'precision:', env.dist_destination)
        if done:
            episode_memory.update_memory_done(env.img_info, env.atom_absolute_nm, env.atom_relative_nm)
            episode_memory.save_memory(folder_name)
            print('Episode reward:', episode_reward)
            break
        else:                
            state=next_state
            
    # if manipulation fails N times, adjust tip conditioning
    
    


        

    if (len(memory)>batch_size):
        episode_K = int(episode_steps)
        for k in range(episode_K):
            c_k = max(int(memory.__len__()*eta**((k)*(1000/episode_K))), 500)
            agent.update_parameters(memory, batch_size, c_k)
# Out:
# Episode: 0
# offffset0000 [39.99775658 39.99775658]
# The scan will take 12.5 seconds
# offset_test0000 [39.99775658 39.99775658]
# offset_test1111 [39.99775658 39.99775658]
# offset_test2222 [39.99775658 39.99775658]
# [[ 4.57409828e-03  4.75422011e-03  4.64299444e-03 ...  1.25476703e-03
#    1.31258013e-03  1.13125940e-03]
#  [-9.43183073e-05 -3.55986101e-04 -4.38601542e-04 ...  1.41551877e-03
#    1.34601635e-03  1.58836543e-03]
#  [ 3.86152743e-04  5.16683512e-04  4.55048906e-04 ... -1.50886591e-03
#   -1.49015346e-03 -1.54916546e-03]
#  ...
#  [ 1.45730134e-03  1.56971230e-03  1.56267555e-03 ...  7.78694278e-04
#    7.22304880e-04  6.37066835e-04]
#  [-4.69063163e-04 -5.56685394e-04 -5.22237313e-04 ... -8.64428956e-04
#   -7.07672144e-04 -5.66889376e-04]
#  [-1.58194348e-03 -1.40682843e-03 -1.39598379e-03 ... -5.00783009e-04
#   -6.63983930e-04 -8.53172476e-04]] 0.003634965699172096
# [[ 1.62357570e-03  1.64786345e-03  1.30594026e-03 ...  2.58172629e-03
#    2.51779917e-03  2.59930737e-03]
#  [ 1.74509150e-03  1.64468633e-03  1.37786499e-03 ... -1.38515970e-03
#   -1.39210479e-03 -1.46127712e-03]
#  [-2.27138556e-03 -2.15864452e-03 -1.97318581e-03 ... -1.53424899e-03
#   -1.42651474e-03 -1.23318822e-03]
#  ...
#  [-4.34626457e-04 -2.33432123e-04  1.18696477e-05 ...  3.14589009e-03
#    3.49776496e-03  3.74044413e-03]
#  [ 3.06838005e-03  3.21998332e-03  2.93504217e-03 ... -1.84179885e-04
#   -3.05327470e-04 -7.57613250e-05]
#  [-9.29977201e-04 -1.06662199e-03 -1.00847881e-03 ... -1.06592947e-03
#   -1.44194651e-03 -1.78673073e-03]] 0.0055801738108093735
# Warning: atom is out of limit
# pulling atom back to center
# C:\Users\wun2\github\Atom_manipulation_with_RL_0523\AMRL\Environment\get_atom_coordinate.py:382: FutureWarning: `selem` is a deprecated argument name for `binary_dilation`. It will be removed in version 1.0. Please use `footprint` instead.
#   r = morphology.binary_dilation(maxima, selem=diamond)
# The scan will take 12.5 seconds
# offset_test0000 [39.99775658 39.99775658]
# offset_test1111 [39.99775658 39.99775658]
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17432\79567060.py in <module>
#       8     done = False
#       9     print('offffset0000',env.offset_nm)
# ---> 10     state, info = env.reset(update_conv_net=False)
#      11     print(state, info)
#      12
#
# ~\github\Atom_manipulation_with_RL_0523\AMRL\Environment\Env_new.py in reset(self, update_conv_net)
#     109             print('Warning: atom is out of limit')
#     110             self.pull_atom_back()
# --> 111             self.atom_absolute_nm, self.atom_relative_nm = self.scan_atom()
#     112         #goal_nm is set between 0.28 - 2 nm
#     113         goal_nm = self.lattice_constant + np.random.random()*(self.goal_nm - self.lattice_constant)
#
# ~\github\Atom_manipulation_with_RL_0523\AMRL\Environment\Env_new.py in scan_atom(self)
#     216                 atom position relative to the template position in STM coordinates (nm)
#     217         """
# --> 218         img_forward, img_backward, offset_nm, len_nm = self.createc_controller.scan_image()
#     219         self.img_info = {'img_forward':img_forward,'img_backward':img_backward, 'offset_nm':offset_nm, 'len_nm':len_nm}
#     220
#
# ~\github\Atom_manipulation_with_RL_0523\AMRL\Environment\createc_control.py in scan_image(self, DIR_NAME, BASE_NAME, counter, save, speed)
#     115         while True:
#     116             time.sleep(2)
# --> 117             scanstatus = self.stm.scanstatus
#     118             if scanstatus!=2:
#     119                 break
#
# ~\Anaconda3\lib\site-packages\win32com\client\dynamic.py in __getattr__(self, attr)
#     626             )
#     627             try:
# --> 628                 ret = self._oleobj_.Invoke(retEntry.dispid, 0, invoke_type, 1)
#     629             except pythoncom.com_error as details:
#     630                 if details.hresult in ERRORS_BAD_CONTEXT:
#
# com_error: (-2147023174, 'The RPC server is unavailable.', None, None)

# %%
env.createc_controller.stm.scanstop()

# %%
env.createc_controller.get_offset_nm()

# %%
env.createc_controller.set_xy_nm(np.array([-50, 90]))

# %%
createc_controller.set_xy_nm(np.array([-50, 90]))

# %%
env.createc_controller.stm.setparam('OffsetX', '23000')
env.createc_controller.stm.setparam('OffsetY', '-45000')

# %%
num_no_done = 0
max_episode = 10
for i_episode in range(episode_start,episode_start+num_episodes):
    print('Episode:', i_episode)
    episode_reward, episode_steps = 0, 0
    done = False
    state, info = env.reset(update_conv_net=False)
    
 # detect atoms   

#  no debris

# crash or no probe-atom contact
    
    
    show_reset(env.img_info, env.atom_start_absolute_nm, env.destination_absolute_nm,
               env.template_nm, env.template_wh)
    episode_memory.update_memory_reset(env.img_info, i_episode, info)
    


    for step in range(max_steps):
        action = agent.select_action(state)
        old_atom_nm = env.atom_absolute_nm
        next_state, reward, done, info = env.step(action)
        episode_steps+=1
        episode_reward+=reward
        mask = float(not done)
        memory.push(state,action,reward,next_state,mask)
        episode_memory.update_memory_step(state, action, next_state, reward, done, info)
        print(info)
        show_step(env.img_info, info['start_nm']+old_atom_nm, info['end_nm']+old_atom_nm,
                    env.atom_absolute_nm, env.atom_start_absolute_nm, 
                    env.destination_absolute_nm, action[4]*env.max_mvolt, 
                    action[5]*env.max_pcurrent_to_mvolt_ratio*action[4]*env.max_mvolt, 
                    env.template_nm, env.template_wh)
        print('step:', step,'reward', reward, 'precision:', env.dist_destination)
        if done:
            episode_memory.update_memory_done(env.img_info, env.atom_absolute_nm, env.atom_relative_nm)
            episode_memory.save_memory(folder_name)
            print('Episode reward:', episode_reward)
            break
        else:                
            state=next_state
            
    # if manipulation fails N times, adjust tip conditioning

    if not done:
        num_no_done+= 1
        if num_no_done > max_episode:
            ID= compositionID(tip_x, tip_y)
            forbiden_area =  markForbiddenArea(actID=0, multiplier=(np.sqrt(float(self.noDebresCounter))*0.5) )
            tip_x_new, tip_y_new = New_tippos(tip_x, tip_y, forbiden:area) # 
            tip_z = Createc_Controller.set_z() # 
            tip_x_new, tip_y_new = New_tippos(tip_x, tip_y, forbiden:area) 
            createc_controller.set(dip, bias voltage)  # change
    else:
        num_no_done = 0
        

    if (len(memory)>batch_size):
        episode_K = int(episode_steps)
        for k in range(episode_K):
            c_k = max(int(memory.__len__()*eta**((k)*(1000/episode_K))), 500)
            agent.update_parameters(memory, batch_size, c_k)

# %% [markdown]
# ### Define the training function

# %%
env.dist_destination=0.3934795995776328

# %% [markdown]
# ### Train the RL agent

# %%
import numpy as np

# %%
data=np.load('training_data_and_model_parameters/training_data/00500.npy',allow_pickle=True).item()

# %%
data['episode_start_info'].keys()

# %%
data['episode_start_info']['info']

# %%
data['episode_end_info']['atom_absolute_nm']

# %%
data['episode_end_info']['atom_relative_nm']

# %%
data['episode_end_info'].keys()

# %%
data['transitions'].keys()

# %%
data['transitions']['reward']

# %%
data['transitions']['done']

# %%
data['transitions']['info'][0].keys()

# %%
data['transitions']['info'][2].keys()

# %%
len(data['transitions']['info'])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(9,9))
for i in range(5):
     plt.subplot(5,2,i*2+1)
     plt.imshow(data['transitions']['info'][i]['img_info']['img_forward'])
     plt.subplot(5,2,i*2+2)
     plt.imshow(data['transitions']['info'][i]['img_info']['img_backward'])

# %%
data['transitions']['state']

# %%
data['transitions']['action']

# %%
data['transitions']['next_state']

# %%
data['episode_start_info']

# %%
plt.imshow(data['episode_end_info']['img_forward'])

# %%
plt.imshow(data['episode_end_info']['img_backward'])

# %%
plt.imshow(data['episode_start_info']['img_forward'])

# %%
plt.imshow(data['episode_start_info']['img_backward'])

# %%
sac_train(episode_start = 2887,num_episodes = 1000)
